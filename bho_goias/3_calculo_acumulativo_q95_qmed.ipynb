# %%
import pandas as pd 
import geopandas as gpd

# %%
bho_centros_superficie = gpd.read_file('D:\\matheus.cgomes\\Documentos\\GitHub\\gis_automations\\data\\26-06-2024\\centros_superficie_bho_vfinal_26-06-2024.gpkg')

areas_incrementais_estacoes = gpd.read_file('D:\\matheus.cgomes\\Documentos\\GitHub\\gis_automations\\data\\26-06-2024\\area_incremental_67_estacoes_26-06-2024.gpkg')

# %%
areas_incrementais_estacoes['codigo'] = areas_incrementais_estacoes['codigo'].astype(int)
bho_centros_superficie['codigo'] = bho_centros_superficie['codigo'].astype(int)

# %%
areas_incrementais_estacoes.info(verbose=True)
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 67 entries, 0 to 66
# Data columns (total 100 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   cobacia_referencia        67 non-null     object
#  1   dra_pk                    67 non-null     float64
#  2   idbacia                   67 non-null     float64
#  3   cotrecho                  67 non-null     float64
#  4   cocursodag                67 non-null     object
#  5   cobacia                   67 non-null     object
#  6   nuareacont                67 non-null     float64
#  7   nuordemcda                67 non-null     float64
#  8   nunivotto1                67 non-null     object
#  9   nunivotto2                67 non-null     object
#  10  nunivotto3                67 non-null     object
#  11  nunivotto4                67 non-null     object
#  12  nunivotto5                67 non-null     object
# ...

# %%
bho_centros_superficie_filtered = bho_centros_superficie[['id', 'cobacia', 'cocursodag', 'noorigem', 'nodestino', 'nucomptrec', 'nudistbact',
 'nudistcdag', 'nuareacont', 'nuareamont', 'nogenerico', 'noligacao', 'noespecif', 'noriocomp', 'nooriginal', 'cocdadesag', 'nutrjus', 'nudistbacc',
 'nuareabacc', 'nuordemcda', 'nucompcda', 'nunivotto', 'nunivotcda', 'nustrahler', 'dedominial', 'dsversao', 'codigo', 'nome', 'ugh', 'estacao_qe',
 'cobacia_jus','geometry']]

# %%
def union_areas_incrementais_centros_superf(centros_superficie,areas_incrementais):
    union2_qmed_points = pd.merge(centros_superficie,areas_incrementais[['codigo','qmed_esp_inc_jan_l/s/km2',
       'qmed_esp_inc_fev_l/s/km2', 'qmed_esp_inc_mar_l/s/km2',
       'qmed_esp_inc_abr_l/s/km2', 'qmed_esp_inc_mai_l/s/km2',
       'qmed_esp_inc_jun_l/s/km2', 'qmed_esp_inc_jul_l/s/km2',
       'qmed_esp_inc_ago_l/s/km2', 'qmed_esp_inc_set_l/s/km2',
       'qmed_esp_inc_out_l/s/km2', 'qmed_esp_inc_nov_l/s/km2',
       'qmed_esp_inc_dez_l/s/km2', 'q95esp_inc_jan_l/s/km2',
       'q95esp_inc_fev_l/s/km2', 'q95esp_inc_mar_l/s/km2',
       'q95esp_inc_abr_l/s/km2', 'q95esp_inc_mai_l/s/km2',
       'q95esp_inc_jun_l/s/km2', 'q95esp_inc_jul_l/s/km2',
       'q95esp_inc_ago_l/s/km2', 'q95esp_inc_set_l/s/km2',
       'q95esp_inc_out_l/s/km2', 'q95esp_inc_nov_l/s/km2',
       'q95esp_inc_dez_l/s/km2','q95anualesp_inc_l/s/km2']],on='codigo',how='inner')
    
    columns_to_convert = ['qmed_esp_inc_jan_l/s/km2',
       'qmed_esp_inc_fev_l/s/km2', 'qmed_esp_inc_mar_l/s/km2',
       'qmed_esp_inc_abr_l/s/km2', 'qmed_esp_inc_mai_l/s/km2',
       'qmed_esp_inc_jun_l/s/km2', 'qmed_esp_inc_jul_l/s/km2',
       'qmed_esp_inc_ago_l/s/km2', 'qmed_esp_inc_set_l/s/km2',
       'qmed_esp_inc_out_l/s/km2', 'qmed_esp_inc_nov_l/s/km2',
       'qmed_esp_inc_dez_l/s/km2', 'q95esp_inc_jan_l/s/km2',
       'q95esp_inc_fev_l/s/km2', 'q95esp_inc_mar_l/s/km2',
       'q95esp_inc_abr_l/s/km2', 'q95esp_inc_mai_l/s/km2',
       'q95esp_inc_jun_l/s/km2', 'q95esp_inc_jul_l/s/km2',
       'q95esp_inc_ago_l/s/km2', 'q95esp_inc_set_l/s/km2',
       'q95esp_inc_out_l/s/km2', 'q95esp_inc_nov_l/s/km2',
       'q95esp_inc_dez_l/s/km2']
    
    '''for column in columns_to_convert:
         union2_qmed_points[column] = union2_qmed_points[column].str.replace(',','.').astype(float)'''

    return union2_qmed_points

# %%
def corrige_bho_q95(bho):
    empty_gdf = pd.DataFrame()

   

    
    bho['q95_jan_ls']  = bho['q95esp_inc_jan_l/s/km2'] * bho['nuareamont'] 
    bho['q95_fev_ls']  = bho['q95esp_inc_fev_l/s/km2'] * bho['nuareamont'] 
    bho['q95_mar_ls']  = bho['q95esp_inc_mar_l/s/km2'] * bho['nuareamont'] 
    bho['q95_abr_ls']  = bho['q95esp_inc_abr_l/s/km2'] * bho['nuareamont'] 
    bho['q95_mai_ls']  = bho['q95esp_inc_mai_l/s/km2'] * bho['nuareamont'] 
    bho['q95_jun_ls']  = bho['q95esp_inc_jun_l/s/km2'] * bho['nuareamont'] 
    bho['q95_jul_ls']  = bho['q95esp_inc_jul_l/s/km2'] * bho['nuareamont'] 
    bho['q95_ago_ls']  = bho['q95esp_inc_ago_l/s/km2'] * bho['nuareamont'] 
    bho['q95_set_ls']  = bho['q95esp_inc_set_l/s/km2'] * bho['nuareamont'] 
    bho['q95_out_ls']  = bho['q95esp_inc_out_l/s/km2'] * bho['nuareamont'] 
    bho['q95_nov_ls']  = bho['q95esp_inc_nov_l/s/km2'] * bho['nuareamont'] 
    bho['q95_dez_ls']  = bho['q95esp_inc_dez_l/s/km2'] * bho['nuareamont']

    bho['vaz_increment_jan_ls'] = bho['nuareacont'] * bho['q95esp_inc_jan_l/s/km2']
    bho['vaz_increment_fev_ls'] = bho['nuareacont'] * bho['q95esp_inc_fev_l/s/km2']
    bho['vaz_increment_mar_ls'] = bho['nuareacont'] * bho['q95esp_inc_mar_l/s/km2']
    bho['vaz_increment_abr_ls'] = bho['nuareacont'] * bho['q95esp_inc_abr_l/s/km2']
    bho['vaz_increment_mai_ls'] = bho['nuareacont'] * bho['q95esp_inc_mai_l/s/km2']
    bho['vaz_increment_jun_ls'] = bho['nuareacont'] * bho['q95esp_inc_jun_l/s/km2']
    bho['vaz_increment_jul_ls'] = bho['nuareacont'] * bho['q95esp_inc_jul_l/s/km2']
    bho['vaz_increment_ago_ls'] = bho['nuareacont'] * bho['q95esp_inc_ago_l/s/km2']
    bho['vaz_increment_set_ls'] = bho['nuareacont'] * bho['q95esp_inc_set_l/s/km2']
    bho['vaz_increment_out_ls'] = bho['nuareacont'] * bho['q95esp_inc_out_l/s/km2']
    bho['vaz_increment_nov_ls'] = bho['nuareacont'] * bho['q95esp_inc_nov_l/s/km2']
    bho['vaz_increment_dez_ls'] = bho['nuareacont'] * bho['q95esp_inc_dez_l/s/km2']

    

    filtro_order1 = (bho['nustrahler'] == 1)
    filtro_order2 = (bho['nustrahler'] == 2)
    filtro_order3 = (bho['nustrahler'] == 3)
    filtro_order4 = (bho['nustrahler'] == 4)
    filtro_order5 = (bho['nustrahler'] == 5)
    filtro_order6 = (bho['nustrahler'] == 6)
    filtro_order7 = (bho['nustrahler'] == 7)
    filtro_order8 = (bho['nustrahler'] == 8)
    filtro_order9 = (bho['nustrahler'] == 9)


    bho.loc[filtro_order1,'situacao_trecho'] = 'calculado'
    
    primeira_ordem = bho.loc[filtro_order1]
    segunda_ordem = bho.loc[filtro_order2] 
    terceira_ordem = bho.loc[filtro_order3] 
    quarta_ordem = bho.loc[filtro_order4] 
    quinta_ordem = bho.loc[filtro_order5] 
    sexta_ordem = bho.loc[filtro_order6] 
    setima_ordem = bho.loc[filtro_order7] 



    bho['new_q95_jan_ls'] = bho['q95_jan_ls']
    bho['new_q95_fev_ls'] = bho['q95_fev_ls']
    bho['new_q95_mar_ls'] = bho['q95_mar_ls']
    bho['new_q95_abr_ls'] = bho['q95_abr_ls']
    bho['new_q95_mai_ls'] = bho['q95_mai_ls']
    bho['new_q95_jun_ls'] = bho['q95_jun_ls']
    bho['new_q95_jul_ls'] = bho['q95_jul_ls']
    bho['new_q95_ago_ls'] = bho['q95_ago_ls']
    bho['new_q95_set_ls'] = bho['q95_set_ls']
    bho['new_q95_out_ls'] = bho['q95_out_ls']
    bho['new_q95_nov_ls'] = bho['q95_nov_ls']
    bho['new_q95_dez_ls'] = bho['q95_dez_ls']
    

    

    
    for idx,row in bho.loc[filtro_order2].iterrows():
        if bho.at[idx,'situacao_trecho']!= 'calculado':


            curso_principal_2_ordem = bho.loc[bho['cocursodag']==row['cocursodag']]
            curso_principal_2_ordem.sort_values(by='cobacia',ascending=False,inplace=True)

            for idx2, row2 in curso_principal_2_ordem.iterrows():
                tributarios = bho.loc[bho['nodestino'] == row2['noorigem']]

                bho.at[idx2, 'new_q95_jan_ls'] = ((tributarios['new_q95_jan_ls'].sum())+row2['vaz_increment_jan_ls'])
                bho.at[idx2, 'new_q95_fev_ls'] = ((tributarios['new_q95_fev_ls'].sum())+row2['vaz_increment_fev_ls'])
                bho.at[idx2, 'new_q95_mar_ls'] = ((tributarios['new_q95_mar_ls'].sum())+row2['vaz_increment_mar_ls'])
                bho.at[idx2, 'new_q95_abr_ls'] = ((tributarios['new_q95_abr_ls'].sum())+row2['vaz_increment_abr_ls'])
                bho.at[idx2, 'new_q95_mai_ls'] = ((tributarios['new_q95_mai_ls'].sum())+row2['vaz_increment_mai_ls'])
                bho.at[idx2, 'new_q95_jun_ls'] = ((tributarios['new_q95_jun_ls'].sum())+row2['vaz_increment_jun_ls'])
                bho.at[idx2, 'new_q95_jul_ls'] = ((tributarios['new_q95_jul_ls'].sum())+row2['vaz_increment_jul_ls'])
                bho.at[idx2, 'new_q95_ago_ls'] = ((tributarios['new_q95_ago_ls'].sum())+row2['vaz_increment_ago_ls'])
                bho.at[idx2, 'new_q95_set_ls'] = ((tributarios['new_q95_set_ls'].sum())+row2['vaz_increment_set_ls'])
                bho.at[idx2, 'new_q95_out_ls'] = ((tributarios['new_q95_out_ls'].sum())+row2['vaz_increment_out_ls'])
                bho.at[idx2, 'new_q95_nov_ls'] = ((tributarios['new_q95_nov_ls'].sum())+row2['vaz_increment_nov_ls'])
                bho.at[idx2, 'new_q95_dez_ls'] = ((tributarios['new_q95_dez_ls'].sum())+row2['vaz_increment_dez_ls'])


                bho.at[idx2, 'situacao_trecho'] = 'calculado'
    
    for idx,row in bho.loc[filtro_order3].iterrows():
        if bho.at[idx,'situacao_trecho']!= 'calculado':

            curso_principal_3_ordem = bho.loc[bho['cocursodag']==row['cocursodag']]
            curso_principal_3_ordem.sort_values(by='cobacia',ascending=False,inplace=True)

            for idx3, row3 in curso_principal_3_ordem.iterrows():
                tributarios = bho.loc[bho['nodestino'] == row3['noorigem']]

                bho.at[idx3, 'new_q95_jan_ls'] = ((tributarios['new_q95_jan_ls'].sum())+row3['vaz_increment_jan_ls'])
                bho.at[idx3, 'new_q95_fev_ls'] = ((tributarios['new_q95_fev_ls'].sum())+row3['vaz_increment_fev_ls'])
                bho.at[idx3, 'new_q95_mar_ls'] = ((tributarios['new_q95_mar_ls'].sum())+row3['vaz_increment_mar_ls'])
                bho.at[idx3, 'new_q95_abr_ls'] = ((tributarios['new_q95_abr_ls'].sum())+row3['vaz_increment_abr_ls'])
                bho.at[idx3, 'new_q95_mai_ls'] = ((tributarios['new_q95_mai_ls'].sum())+row3['vaz_increment_mai_ls'])
                bho.at[idx3, 'new_q95_jun_ls'] = ((tributarios['new_q95_jun_ls'].sum())+row3['vaz_increment_jun_ls'])
                bho.at[idx3, 'new_q95_jul_ls'] = ((tributarios['new_q95_jul_ls'].sum())+row3['vaz_increment_jul_ls'])
                bho.at[idx3, 'new_q95_ago_ls'] = ((tributarios['new_q95_ago_ls'].sum())+row3['vaz_increment_ago_ls'])
                bho.at[idx3, 'new_q95_set_ls'] = ((tributarios['new_q95_set_ls'].sum())+row3['vaz_increment_set_ls'])
                bho.at[idx3, 'new_q95_out_ls'] = ((tributarios['new_q95_out_ls'].sum())+row3['vaz_increment_out_ls'])
                bho.at[idx3, 'new_q95_nov_ls'] = ((tributarios['new_q95_nov_ls'].sum())+row3['vaz_increment_nov_ls'])
                bho.at[idx3, 'new_q95_dez_ls'] = ((tributarios['new_q95_dez_ls'].sum())+row3['vaz_increment_dez_ls'])


                bho.at[idx3, 'situacao_trecho'] = 'calculado'
    
    for idx,row in bho.loc[filtro_order4].iterrows():
        if bho.at[idx,'situacao_trecho']!= 'calculado':

            curso_principal_4_ordem = bho.loc[bho['cocursodag']==row['cocursodag']]
            curso_principal_4_ordem.sort_values(by='cobacia',ascending=False,inplace=True)

            for idx4, row4 in curso_principal_4_ordem.iterrows():
                tributarios = bho.loc[bho['nodestino'] == row4['noorigem']]

                bho.at[idx4, 'new_q95_jan_ls'] = ((tributarios['new_q95_jan_ls'].sum())+row4['vaz_increment_jan_ls'])
                bho.at[idx4, 'new_q95_fev_ls'] = ((tributarios['new_q95_fev_ls'].sum())+row4['vaz_increment_fev_ls'])
                bho.at[idx4, 'new_q95_mar_ls'] = ((tributarios['new_q95_mar_ls'].sum())+row4['vaz_increment_mar_ls'])
                bho.at[idx4, 'new_q95_abr_ls'] = ((tributarios['new_q95_abr_ls'].sum())+row4['vaz_increment_abr_ls'])
                bho.at[idx4, 'new_q95_mai_ls'] = ((tributarios['new_q95_mai_ls'].sum())+row4['vaz_increment_mai_ls'])
                bho.at[idx4, 'new_q95_jun_ls'] = ((tributarios['new_q95_jun_ls'].sum())+row4['vaz_increment_jun_ls'])
                bho.at[idx4, 'new_q95_jul_ls'] = ((tributarios['new_q95_jul_ls'].sum())+row4['vaz_increment_jul_ls'])
                bho.at[idx4, 'new_q95_ago_ls'] = ((tributarios['new_q95_ago_ls'].sum())+row4['vaz_increment_ago_ls'])
                bho.at[idx4, 'new_q95_set_ls'] = ((tributarios['new_q95_set_ls'].sum())+row4['vaz_increment_set_ls'])
                bho.at[idx4, 'new_q95_out_ls'] = ((tributarios['new_q95_out_ls'].sum())+row4['vaz_increment_out_ls'])
                bho.at[idx4, 'new_q95_nov_ls'] = ((tributarios['new_q95_nov_ls'].sum())+row4['vaz_increment_nov_ls'])
                bho.at[idx4, 'new_q95_dez_ls'] = ((tributarios['new_q95_dez_ls'].sum())+row4['vaz_increment_dez_ls'])


                bho.at[idx4, 'situacao_trecho'] = 'calculado'
    
    for idx,row in bho.loc[filtro_order5].iterrows():
        if bho.at[idx,'situacao_trecho']!= 'calculado':

            curso_principal_5_ordem = bho.loc[bho['cocursodag']==row['cocursodag']]
            curso_principal_5_ordem.sort_values(by='cobacia',ascending=False,inplace=True)

            for idx5, row5 in curso_principal_5_ordem.iterrows():
                tributarios = bho.loc[bho['nodestino'] == row5['noorigem']]

                bho.at[idx5, 'new_q95_jan_ls'] = ((tributarios['new_q95_jan_ls'].sum())+row5['vaz_increment_jan_ls'])
                bho.at[idx5, 'new_q95_fev_ls'] = ((tributarios['new_q95_fev_ls'].sum())+row5['vaz_increment_fev_ls'])
                bho.at[idx5, 'new_q95_mar_ls'] = ((tributarios['new_q95_mar_ls'].sum())+row5['vaz_increment_mar_ls'])
                bho.at[idx5, 'new_q95_abr_ls'] = ((tributarios['new_q95_abr_ls'].sum())+row5['vaz_increment_abr_ls'])
                bho.at[idx5, 'new_q95_mai_ls'] = ((tributarios['new_q95_mai_ls'].sum())+row5['vaz_increment_mai_ls'])
                bho.at[idx5, 'new_q95_jun_ls'] = ((tributarios['new_q95_jun_ls'].sum())+row5['vaz_increment_jun_ls'])
                bho.at[idx5, 'new_q95_jul_ls'] = ((tributarios['new_q95_jul_ls'].sum())+row5['vaz_increment_jul_ls'])
                bho.at[idx5, 'new_q95_ago_ls'] = ((tributarios['new_q95_ago_ls'].sum())+row5['vaz_increment_ago_ls'])
                bho.at[idx5, 'new_q95_set_ls'] = ((tributarios['new_q95_set_ls'].sum())+row5['vaz_increment_set_ls'])
                bho.at[idx5, 'new_q95_out_ls'] = ((tributarios['new_q95_out_ls'].sum())+row5['vaz_increment_out_ls'])
                bho.at[idx5, 'new_q95_nov_ls'] = ((tributarios['new_q95_nov_ls'].sum())+row5['vaz_increment_nov_ls'])
                bho.at[idx5, 'new_q95_dez_ls'] = ((tributarios['new_q95_dez_ls'].sum())+row5['vaz_increment_dez_ls'])


                bho.at[idx5, 'situacao_trecho'] = 'calculado'

    for idx,row in bho.loc[filtro_order6].iterrows():
        if bho.at[idx,'situacao_trecho']!= 'calculado':

            curso_principal_6_ordem = bho.loc[bho['cocursodag']==row['cocursodag']]
            curso_principal_6_ordem.sort_values(by='cobacia',ascending=False,inplace=True)

            for idx5, row6 in curso_principal_6_ordem.iterrows():
                tributarios = bho.loc[bho['nodestino'] == row6['noorigem']]

                bho.at[idx5, 'new_q95_jan_ls'] = ((tributarios['new_q95_jan_ls'].sum())+row6['vaz_increment_jan_ls'])
                bho.at[idx5, 'new_q95_fev_ls'] = ((tributarios['new_q95_fev_ls'].sum())+row6['vaz_increment_fev_ls'])
                bho.at[idx5, 'new_q95_mar_ls'] = ((tributarios['new_q95_mar_ls'].sum())+row6['vaz_increment_mar_ls'])
                bho.at[idx5, 'new_q95_abr_ls'] = ((tributarios['new_q95_abr_ls'].sum())+row6['vaz_increment_abr_ls'])
                bho.at[idx5, 'new_q95_mai_ls'] = ((tributarios['new_q95_mai_ls'].sum())+row6['vaz_increment_mai_ls'])
                bho.at[idx5, 'new_q95_jun_ls'] = ((tributarios['new_q95_jun_ls'].sum())+row6['vaz_increment_jun_ls'])
                bho.at[idx5, 'new_q95_jul_ls'] = ((tributarios['new_q95_jul_ls'].sum())+row6['vaz_increment_jul_ls'])
                bho.at[idx5, 'new_q95_ago_ls'] = ((tributarios['new_q95_ago_ls'].sum())+row6['vaz_increment_ago_ls'])
                bho.at[idx5, 'new_q95_set_ls'] = ((tributarios['new_q95_set_ls'].sum())+row6['vaz_increment_set_ls'])
                bho.at[idx5, 'new_q95_out_ls'] = ((tributarios['new_q95_out_ls'].sum())+row6['vaz_increment_out_ls'])
                bho.at[idx5, 'new_q95_nov_ls'] = ((tributarios['new_q95_nov_ls'].sum())+row6['vaz_increment_nov_ls'])
                bho.at[idx5, 'new_q95_dez_ls'] = ((tributarios['new_q95_dez_ls'].sum())+row6['vaz_increment_dez_ls'])


                bho.at[idx5, 'situacao_trecho'] = 'calculado'
    

    for idx,row in bho.loc[filtro_order7].iterrows():
        if bho.at[idx,'situacao_trecho']!= 'calculado':

            curso_principal_7_ordem = bho.loc[bho['cocursodag']==row['cocursodag']]
            curso_principal_7_ordem.sort_values(by='cobacia',ascending=False,inplace=True)

            for idx7, row7 in curso_principal_7_ordem.iterrows():
                tributarios = bho.loc[bho['nodestino'] == row7['noorigem']]

                bho.at[idx7, 'new_q95_jan_ls'] = ((tributarios['new_q95_jan_ls'].sum())+row7['vaz_increment_jan_ls'])
                bho.at[idx7, 'new_q95_fev_ls'] = ((tributarios['new_q95_fev_ls'].sum())+row7['vaz_increment_fev_ls'])
                bho.at[idx7, 'new_q95_mar_ls'] = ((tributarios['new_q95_mar_ls'].sum())+row7['vaz_increment_mar_ls'])
                bho.at[idx7, 'new_q95_abr_ls'] = ((tributarios['new_q95_abr_ls'].sum())+row7['vaz_increment_abr_ls'])
                bho.at[idx7, 'new_q95_mai_ls'] = ((tributarios['new_q95_mai_ls'].sum())+row7['vaz_increment_mai_ls'])
                bho.at[idx7, 'new_q95_jun_ls'] = ((tributarios['new_q95_jun_ls'].sum())+row7['vaz_increment_jun_ls'])
                bho.at[idx7, 'new_q95_jul_ls'] = ((tributarios['new_q95_jul_ls'].sum())+row7['vaz_increment_jul_ls'])
                bho.at[idx7, 'new_q95_ago_ls'] = ((tributarios['new_q95_ago_ls'].sum())+row7['vaz_increment_ago_ls'])
                bho.at[idx7, 'new_q95_set_ls'] = ((tributarios['new_q95_set_ls'].sum())+row7['vaz_increment_set_ls'])
                bho.at[idx7, 'new_q95_out_ls'] = ((tributarios['new_q95_out_ls'].sum())+row7['vaz_increment_out_ls'])
                bho.at[idx7, 'new_q95_nov_ls'] = ((tributarios['new_q95_nov_ls'].sum())+row7['vaz_increment_nov_ls'])
                bho.at[idx7, 'new_q95_dez_ls'] = ((tributarios['new_q95_dez_ls'].sum())+row7['vaz_increment_dez_ls'])


                bho.at[idx7, 'situacao_trecho'] = 'calculado'

    for idx,row in bho.loc[filtro_order8].iterrows():
        if bho.at[idx,'situacao_trecho']!= 'calculado':

            curso_principal_8_ordem = bho.loc[bho['cocursodag']==row['cocursodag']]
            curso_principal_8_ordem.sort_values(by='cobacia',ascending=False,inplace=True)

            for idx8, row8 in curso_principal_8_ordem.iterrows():
                tributarios = bho.loc[bho['nodestino'] == row8['noorigem']]

                bho.at[idx8, 'new_q95_jan_ls'] = ((tributarios['new_q95_jan_ls'].sum())+row8['vaz_increment_jan_ls'])
                bho.at[idx8, 'new_q95_fev_ls'] = ((tributarios['new_q95_fev_ls'].sum())+row8['vaz_increment_fev_ls'])
                bho.at[idx8, 'new_q95_mar_ls'] = ((tributarios['new_q95_mar_ls'].sum())+row8['vaz_increment_mar_ls'])
                bho.at[idx8, 'new_q95_abr_ls'] = ((tributarios['new_q95_abr_ls'].sum())+row8['vaz_increment_abr_ls'])
                bho.at[idx8, 'new_q95_mai_ls'] = ((tributarios['new_q95_mai_ls'].sum())+row8['vaz_increment_mai_ls'])
                bho.at[idx8, 'new_q95_jun_ls'] = ((tributarios['new_q95_jun_ls'].sum())+row8['vaz_increment_jun_ls'])
                bho.at[idx8, 'new_q95_jul_ls'] = ((tributarios['new_q95_jul_ls'].sum())+row8['vaz_increment_jul_ls'])
                bho.at[idx8, 'new_q95_ago_ls'] = ((tributarios['new_q95_ago_ls'].sum())+row8['vaz_increment_ago_ls'])
                bho.at[idx8, 'new_q95_set_ls'] = ((tributarios['new_q95_set_ls'].sum())+row8['vaz_increment_set_ls'])
                bho.at[idx8, 'new_q95_out_ls'] = ((tributarios['new_q95_out_ls'].sum())+row8['vaz_increment_out_ls'])
                bho.at[idx8, 'new_q95_nov_ls'] = ((tributarios['new_q95_nov_ls'].sum())+row8['vaz_increment_nov_ls'])
                bho.at[idx8, 'new_q95_dez_ls'] = ((tributarios['new_q95_dez_ls'].sum())+row8['vaz_increment_dez_ls'])


                bho.at[idx8, 'situacao_trecho'] = 'calculado'
    

    for idx,row in bho.loc[filtro_order9].iterrows():
        if bho.at[idx,'situacao_trecho']!= 'calculado':

            curso_principal_9_ordem = bho.loc[bho['cocursodag']==row['cocursodag']]
            curso_principal_9_ordem.sort_values(by='cobacia',ascending=False,inplace=True)

            for idx9, row9 in curso_principal_9_ordem.iterrows():
                tributarios = bho.loc[bho['nodestino'] == row9['noorigem']]

                bho.at[idx9, 'new_q95_jan_ls'] = ((tributarios['new_q95_jan_ls'].sum())+row9['vaz_increment_jan_ls'])
                bho.at[idx9, 'new_q95_fev_ls'] = ((tributarios['new_q95_fev_ls'].sum())+row9['vaz_increment_fev_ls'])
                bho.at[idx9, 'new_q95_mar_ls'] = ((tributarios['new_q95_mar_ls'].sum())+row9['vaz_increment_mar_ls'])
                bho.at[idx9, 'new_q95_abr_ls'] = ((tributarios['new_q95_abr_ls'].sum())+row9['vaz_increment_abr_ls'])
                bho.at[idx9, 'new_q95_mai_ls'] = ((tributarios['new_q95_mai_ls'].sum())+row9['vaz_increment_mai_ls'])
                bho.at[idx9, 'new_q95_jun_ls'] = ((tributarios['new_q95_jun_ls'].sum())+row9['vaz_increment_jun_ls'])
                bho.at[idx9, 'new_q95_jul_ls'] = ((tributarios['new_q95_jul_ls'].sum())+row9['vaz_increment_jul_ls'])
                bho.at[idx9, 'new_q95_ago_ls'] = ((tributarios['new_q95_ago_ls'].sum())+row9['vaz_increment_ago_ls'])
                bho.at[idx9, 'new_q95_set_ls'] = ((tributarios['new_q95_set_ls'].sum())+row9['vaz_increment_set_ls'])
                bho.at[idx9, 'new_q95_out_ls'] = ((tributarios['new_q95_out_ls'].sum())+row9['vaz_increment_out_ls'])
                bho.at[idx9, 'new_q95_nov_ls'] = ((tributarios['new_q95_nov_ls'].sum())+row9['vaz_increment_nov_ls'])
                bho.at[idx9, 'new_q95_dez_ls'] = ((tributarios['new_q95_dez_ls'].sum())+row9['vaz_increment_dez_ls'])


                bho.at[idx9, 'situacao_trecho'] = 'calculado'
        

    


    
            
              

    return bho

# %%
def corrige_bho_qmed(bho):
    empty_gdf = pd.DataFrame()

   

    
    bho['qmed_jan_ls']  = bho['qmed_esp_inc_jan_l/s/km2'] * bho['nuareamont'] 
    bho['qmed_fev_ls']  = bho['qmed_esp_inc_fev_l/s/km2'] * bho['nuareamont'] 
    bho['qmed_mar_ls']  = bho['qmed_esp_inc_mar_l/s/km2'] * bho['nuareamont'] 
    bho['qmed_abr_ls']  = bho['qmed_esp_inc_abr_l/s/km2'] * bho['nuareamont'] 
    bho['qmed_mai_ls']  = bho['qmed_esp_inc_mai_l/s/km2'] * bho['nuareamont'] 
    bho['qmed_jun_ls']  = bho['qmed_esp_inc_jun_l/s/km2'] * bho['nuareamont'] 
    bho['qmed_jul_ls']  = bho['qmed_esp_inc_jul_l/s/km2'] * bho['nuareamont'] 
    bho['qmed_ago_ls']  = bho['qmed_esp_inc_ago_l/s/km2'] * bho['nuareamont'] 
    bho['qmed_set_ls']  = bho['qmed_esp_inc_set_l/s/km2'] * bho['nuareamont'] 
    bho['qmed_out_ls']  = bho['qmed_esp_inc_out_l/s/km2'] * bho['nuareamont'] 
    bho['qmed_nov_ls']  = bho['qmed_esp_inc_nov_l/s/km2'] * bho['nuareamont'] 
    bho['qmed_dez_ls']  = bho['qmed_esp_inc_dez_l/s/km2'] * bho['nuareamont'] 

    bho['vaz_qmed_increment_jan_ls'] = bho['nuareacont'] * bho['qmed_esp_inc_jan_l/s/km2']
    bho['vaz_qmed_increment_fev_ls'] = bho['nuareacont'] * bho['qmed_esp_inc_fev_l/s/km2']
    bho['vaz_qmed_increment_mar_ls'] = bho['nuareacont'] * bho['qmed_esp_inc_mar_l/s/km2']
    bho['vaz_qmed_increment_abr_ls'] = bho['nuareacont'] * bho['qmed_esp_inc_abr_l/s/km2']
    bho['vaz_qmed_increment_mai_ls'] = bho['nuareacont'] * bho['qmed_esp_inc_mai_l/s/km2']
    bho['vaz_qmed_increment_jun_ls'] = bho['nuareacont'] * bho['qmed_esp_inc_jun_l/s/km2']
    bho['vaz_qmed_increment_jul_ls'] = bho['nuareacont'] * bho['qmed_esp_inc_jul_l/s/km2']
    bho['vaz_qmed_increment_ago_ls'] = bho['nuareacont'] * bho['qmed_esp_inc_ago_l/s/km2']
    bho['vaz_qmed_increment_set_ls'] = bho['nuareacont'] * bho['qmed_esp_inc_set_l/s/km2']
    bho['vaz_qmed_increment_out_ls'] = bho['nuareacont'] * bho['qmed_esp_inc_out_l/s/km2']
    bho['vaz_qmed_increment_nov_ls'] = bho['nuareacont'] * bho['qmed_esp_inc_nov_l/s/km2']
    bho['vaz_qmed_increment_dez_ls'] = bho['nuareacont'] * bho['qmed_esp_inc_dez_l/s/km2']

    

    filtro_order1 = (bho['nustrahler'] == 1)
    filtro_order2 = (bho['nustrahler'] == 2)
    filtro_order3 = (bho['nustrahler'] == 3)
    filtro_order4 = (bho['nustrahler'] == 4)
    filtro_order5 = (bho['nustrahler'] == 5)
    filtro_order6 = (bho['nustrahler'] == 6)
    filtro_order7 = (bho['nustrahler'] == 7)
    filtro_order8 = (bho['nustrahler'] == 8)
    filtro_order9 = (bho['nustrahler'] == 9)


    bho.loc[filtro_order1,'situacao_trecho'] = 'calculado'
    
    primeira_ordem = bho.loc[filtro_order1]
    segunda_ordem = bho.loc[filtro_order2] 
    terceira_ordem = bho.loc[filtro_order3] 
    quarta_ordem = bho.loc[filtro_order4] 
    quinta_ordem = bho.loc[filtro_order5] 
    sexta_ordem = bho.loc[filtro_order6] 
    setima_ordem = bho.loc[filtro_order7] 



    bho['new_qmed_jan_ls'] = bho['qmed_jan_ls']
    bho['new_qmed_fev_ls'] = bho['qmed_fev_ls']
    bho['new_qmed_mar_ls'] = bho['qmed_mar_ls']
    bho['new_qmed_abr_ls'] = bho['qmed_abr_ls']
    bho['new_qmed_mai_ls'] = bho['qmed_mai_ls']
    bho['new_qmed_jun_ls'] = bho['qmed_jun_ls']
    bho['new_qmed_jul_ls'] = bho['qmed_jul_ls']
    bho['new_qmed_ago_ls'] = bho['qmed_ago_ls']
    bho['new_qmed_set_ls'] = bho['qmed_set_ls']
    bho['new_qmed_out_ls'] = bho['qmed_out_ls']
    bho['new_qmed_nov_ls'] = bho['qmed_nov_ls']
    bho['new_qmed_dez_ls'] = bho['qmed_dez_ls']
    

    

    
    for idx,row in bho.loc[filtro_order2].iterrows():
        if bho.at[idx,'situacao_trecho']!= 'calculado':


            curso_principal_2_ordem = bho.loc[bho['cocursodag']==row['cocursodag']]
            curso_principal_2_ordem.sort_values(by='cobacia',ascending=False,inplace=True)

            for idx2, row2 in curso_principal_2_ordem.iterrows():
                tributarios = bho.loc[bho['nodestino'] == row2['noorigem']]

                bho.at[idx2, 'new_qmed_jan_ls'] = ((tributarios['new_qmed_jan_ls'].sum())+row2['vaz_qmed_increment_jan_ls'])
                bho.at[idx2, 'new_qmed_fev_ls'] = ((tributarios['new_qmed_fev_ls'].sum())+row2['vaz_qmed_increment_fev_ls'])
                bho.at[idx2, 'new_qmed_mar_ls'] = ((tributarios['new_qmed_mar_ls'].sum())+row2['vaz_qmed_increment_mar_ls'])
                bho.at[idx2, 'new_qmed_abr_ls'] = ((tributarios['new_qmed_abr_ls'].sum())+row2['vaz_qmed_increment_abr_ls'])
                bho.at[idx2, 'new_qmed_mai_ls'] = ((tributarios['new_qmed_mai_ls'].sum())+row2['vaz_qmed_increment_mai_ls'])
                bho.at[idx2, 'new_qmed_jun_ls'] = ((tributarios['new_qmed_jun_ls'].sum())+row2['vaz_qmed_increment_jun_ls'])
                bho.at[idx2, 'new_qmed_jul_ls'] = ((tributarios['new_qmed_jul_ls'].sum())+row2['vaz_qmed_increment_jul_ls'])
                bho.at[idx2, 'new_qmed_ago_ls'] = ((tributarios['new_qmed_ago_ls'].sum())+row2['vaz_qmed_increment_ago_ls'])
                bho.at[idx2, 'new_qmed_set_ls'] = ((tributarios['new_qmed_set_ls'].sum())+row2['vaz_qmed_increment_set_ls'])
                bho.at[idx2, 'new_qmed_out_ls'] = ((tributarios['new_qmed_out_ls'].sum())+row2['vaz_qmed_increment_out_ls'])
                bho.at[idx2, 'new_qmed_nov_ls'] = ((tributarios['new_qmed_nov_ls'].sum())+row2['vaz_qmed_increment_nov_ls'])
                bho.at[idx2, 'new_qmed_dez_ls'] = ((tributarios['new_qmed_dez_ls'].sum())+row2['vaz_qmed_increment_dez_ls'])


                bho.at[idx2, 'situacao_trecho'] = 'calculado'
    
    for idx,row in bho.loc[filtro_order3].iterrows():
        if bho.at[idx,'situacao_trecho']!= 'calculado':

            curso_principal_3_ordem = bho.loc[bho['cocursodag']==row['cocursodag']]
            curso_principal_3_ordem.sort_values(by='cobacia',ascending=False,inplace=True)

            for idx3, row3 in curso_principal_3_ordem.iterrows():
                tributarios = bho.loc[bho['nodestino'] == row3['noorigem']]

                bho.at[idx3, 'new_qmed_jan_ls'] = ((tributarios['new_qmed_jan_ls'].sum())+row3['vaz_qmed_increment_jan_ls'])
                bho.at[idx3, 'new_qmed_fev_ls'] = ((tributarios['new_qmed_fev_ls'].sum())+row3['vaz_qmed_increment_fev_ls'])
                bho.at[idx3, 'new_qmed_mar_ls'] = ((tributarios['new_qmed_mar_ls'].sum())+row3['vaz_qmed_increment_mar_ls'])
                bho.at[idx3, 'new_qmed_abr_ls'] = ((tributarios['new_qmed_abr_ls'].sum())+row3['vaz_qmed_increment_abr_ls'])
                bho.at[idx3, 'new_qmed_mai_ls'] = ((tributarios['new_qmed_mai_ls'].sum())+row3['vaz_qmed_increment_mai_ls'])
                bho.at[idx3, 'new_qmed_jun_ls'] = ((tributarios['new_qmed_jun_ls'].sum())+row3['vaz_qmed_increment_jun_ls'])
                bho.at[idx3, 'new_qmed_jul_ls'] = ((tributarios['new_qmed_jul_ls'].sum())+row3['vaz_qmed_increment_jul_ls'])
                bho.at[idx3, 'new_qmed_ago_ls'] = ((tributarios['new_qmed_ago_ls'].sum())+row3['vaz_qmed_increment_ago_ls'])
                bho.at[idx3, 'new_qmed_set_ls'] = ((tributarios['new_qmed_set_ls'].sum())+row3['vaz_qmed_increment_set_ls'])
                bho.at[idx3, 'new_qmed_out_ls'] = ((tributarios['new_qmed_out_ls'].sum())+row3['vaz_qmed_increment_out_ls'])
                bho.at[idx3, 'new_qmed_nov_ls'] = ((tributarios['new_qmed_nov_ls'].sum())+row3['vaz_qmed_increment_nov_ls'])
                bho.at[idx3, 'new_qmed_dez_ls'] = ((tributarios['new_qmed_dez_ls'].sum())+row3['vaz_qmed_increment_dez_ls'])


                bho.at[idx3, 'situacao_trecho'] = 'calculado'
    
    for idx,row in bho.loc[filtro_order4].iterrows():
        if bho.at[idx,'situacao_trecho']!= 'calculado':

            curso_principal_4_ordem = bho.loc[bho['cocursodag']==row['cocursodag']]
            curso_principal_4_ordem.sort_values(by='cobacia',ascending=False,inplace=True)

            for idx4, row4 in curso_principal_4_ordem.iterrows():
                tributarios = bho.loc[bho['nodestino'] == row4['noorigem']]

                bho.at[idx4, 'new_qmed_jan_ls'] = ((tributarios['new_qmed_jan_ls'].sum())+row4['vaz_qmed_increment_jan_ls'])
                bho.at[idx4, 'new_qmed_fev_ls'] = ((tributarios['new_qmed_fev_ls'].sum())+row4['vaz_qmed_increment_fev_ls'])
                bho.at[idx4, 'new_qmed_mar_ls'] = ((tributarios['new_qmed_mar_ls'].sum())+row4['vaz_qmed_increment_mar_ls'])
                bho.at[idx4, 'new_qmed_abr_ls'] = ((tributarios['new_qmed_abr_ls'].sum())+row4['vaz_qmed_increment_abr_ls'])
                bho.at[idx4, 'new_qmed_mai_ls'] = ((tributarios['new_qmed_mai_ls'].sum())+row4['vaz_qmed_increment_mai_ls'])
                bho.at[idx4, 'new_qmed_jun_ls'] = ((tributarios['new_qmed_jun_ls'].sum())+row4['vaz_qmed_increment_jun_ls'])
                bho.at[idx4, 'new_qmed_jul_ls'] = ((tributarios['new_qmed_jul_ls'].sum())+row4['vaz_qmed_increment_jul_ls'])
                bho.at[idx4, 'new_qmed_ago_ls'] = ((tributarios['new_qmed_ago_ls'].sum())+row4['vaz_qmed_increment_ago_ls'])
                bho.at[idx4, 'new_qmed_set_ls'] = ((tributarios['new_qmed_set_ls'].sum())+row4['vaz_qmed_increment_set_ls'])
                bho.at[idx4, 'new_qmed_out_ls'] = ((tributarios['new_qmed_out_ls'].sum())+row4['vaz_qmed_increment_out_ls'])
                bho.at[idx4, 'new_qmed_nov_ls'] = ((tributarios['new_qmed_nov_ls'].sum())+row4['vaz_qmed_increment_nov_ls'])
                bho.at[idx4, 'new_qmed_dez_ls'] = ((tributarios['new_qmed_dez_ls'].sum())+row4['vaz_qmed_increment_dez_ls'])


                bho.at[idx4, 'situacao_trecho'] = 'calculado'
    
    for idx,row in bho.loc[filtro_order5].iterrows():
        if bho.at[idx,'situacao_trecho']!= 'calculado':

            curso_principal_5_ordem = bho.loc[bho['cocursodag']==row['cocursodag']]
            curso_principal_5_ordem.sort_values(by='cobacia',ascending=False,inplace=True)

            for idx5, row5 in curso_principal_5_ordem.iterrows():
                tributarios = bho.loc[bho['nodestino'] == row5['noorigem']]

                bho.at[idx5, 'new_qmed_jan_ls'] = ((tributarios['new_qmed_jan_ls'].sum())+row5['vaz_qmed_increment_jan_ls'])
                bho.at[idx5, 'new_qmed_fev_ls'] = ((tributarios['new_qmed_fev_ls'].sum())+row5['vaz_qmed_increment_fev_ls'])
                bho.at[idx5, 'new_qmed_mar_ls'] = ((tributarios['new_qmed_mar_ls'].sum())+row5['vaz_qmed_increment_mar_ls'])
                bho.at[idx5, 'new_qmed_abr_ls'] = ((tributarios['new_qmed_abr_ls'].sum())+row5['vaz_qmed_increment_abr_ls'])
                bho.at[idx5, 'new_qmed_mai_ls'] = ((tributarios['new_qmed_mai_ls'].sum())+row5['vaz_qmed_increment_mai_ls'])
                bho.at[idx5, 'new_qmed_jun_ls'] = ((tributarios['new_qmed_jun_ls'].sum())+row5['vaz_qmed_increment_jun_ls'])
                bho.at[idx5, 'new_qmed_jul_ls'] = ((tributarios['new_qmed_jul_ls'].sum())+row5['vaz_qmed_increment_jul_ls'])
                bho.at[idx5, 'new_qmed_ago_ls'] = ((tributarios['new_qmed_ago_ls'].sum())+row5['vaz_qmed_increment_ago_ls'])
                bho.at[idx5, 'new_qmed_set_ls'] = ((tributarios['new_qmed_set_ls'].sum())+row5['vaz_qmed_increment_set_ls'])
                bho.at[idx5, 'new_qmed_out_ls'] = ((tributarios['new_qmed_out_ls'].sum())+row5['vaz_qmed_increment_out_ls'])
                bho.at[idx5, 'new_qmed_nov_ls'] = ((tributarios['new_qmed_nov_ls'].sum())+row5['vaz_qmed_increment_nov_ls'])
                bho.at[idx5, 'new_qmed_dez_ls'] = ((tributarios['new_qmed_dez_ls'].sum())+row5['vaz_qmed_increment_dez_ls'])


                bho.at[idx5, 'situacao_trecho'] = 'calculado'

    for idx,row in bho.loc[filtro_order6].iterrows():
        if bho.at[idx,'situacao_trecho']!= 'calculado':

            curso_principal_6_ordem = bho.loc[bho['cocursodag']==row['cocursodag']]
            curso_principal_6_ordem.sort_values(by='cobacia',ascending=False,inplace=True)

            for idx5, row6 in curso_principal_6_ordem.iterrows():
                tributarios = bho.loc[bho['nodestino'] == row6['noorigem']]

                bho.at[idx5, 'new_qmed_jan_ls'] = ((tributarios['new_qmed_jan_ls'].sum())+row6['vaz_qmed_increment_jan_ls'])
                bho.at[idx5, 'new_qmed_fev_ls'] = ((tributarios['new_qmed_fev_ls'].sum())+row6['vaz_qmed_increment_fev_ls'])
                bho.at[idx5, 'new_qmed_mar_ls'] = ((tributarios['new_qmed_mar_ls'].sum())+row6['vaz_qmed_increment_mar_ls'])
                bho.at[idx5, 'new_qmed_abr_ls'] = ((tributarios['new_qmed_abr_ls'].sum())+row6['vaz_qmed_increment_abr_ls'])
                bho.at[idx5, 'new_qmed_mai_ls'] = ((tributarios['new_qmed_mai_ls'].sum())+row6['vaz_qmed_increment_mai_ls'])
                bho.at[idx5, 'new_qmed_jun_ls'] = ((tributarios['new_qmed_jun_ls'].sum())+row6['vaz_qmed_increment_jun_ls'])
                bho.at[idx5, 'new_qmed_jul_ls'] = ((tributarios['new_qmed_jul_ls'].sum())+row6['vaz_qmed_increment_jul_ls'])
                bho.at[idx5, 'new_qmed_ago_ls'] = ((tributarios['new_qmed_ago_ls'].sum())+row6['vaz_qmed_increment_ago_ls'])
                bho.at[idx5, 'new_qmed_set_ls'] = ((tributarios['new_qmed_set_ls'].sum())+row6['vaz_qmed_increment_set_ls'])
                bho.at[idx5, 'new_qmed_out_ls'] = ((tributarios['new_qmed_out_ls'].sum())+row6['vaz_qmed_increment_out_ls'])
                bho.at[idx5, 'new_qmed_nov_ls'] = ((tributarios['new_qmed_nov_ls'].sum())+row6['vaz_qmed_increment_nov_ls'])
                bho.at[idx5, 'new_qmed_dez_ls'] = ((tributarios['new_qmed_dez_ls'].sum())+row6['vaz_qmed_increment_dez_ls'])


                bho.at[idx5, 'situacao_trecho'] = 'calculado'
    

    for idx,row in bho.loc[filtro_order7].iterrows():
        if bho.at[idx,'situacao_trecho']!= 'calculado':

            curso_principal_7_ordem = bho.loc[bho['cocursodag']==row['cocursodag']]
            curso_principal_7_ordem.sort_values(by='cobacia',ascending=False,inplace=True)

            for idx7, row7 in curso_principal_7_ordem.iterrows():
                tributarios = bho.loc[bho['nodestino'] == row7['noorigem']]

                bho.at[idx7, 'new_qmed_jan_ls'] = ((tributarios['new_qmed_jan_ls'].sum())+row7['vaz_qmed_increment_jan_ls'])
                bho.at[idx7, 'new_qmed_fev_ls'] = ((tributarios['new_qmed_fev_ls'].sum())+row7['vaz_qmed_increment_fev_ls'])
                bho.at[idx7, 'new_qmed_mar_ls'] = ((tributarios['new_qmed_mar_ls'].sum())+row7['vaz_qmed_increment_mar_ls'])
                bho.at[idx7, 'new_qmed_abr_ls'] = ((tributarios['new_qmed_abr_ls'].sum())+row7['vaz_qmed_increment_abr_ls'])
                bho.at[idx7, 'new_qmed_mai_ls'] = ((tributarios['new_qmed_mai_ls'].sum())+row7['vaz_qmed_increment_mai_ls'])
                bho.at[idx7, 'new_qmed_jun_ls'] = ((tributarios['new_qmed_jun_ls'].sum())+row7['vaz_qmed_increment_jun_ls'])
                bho.at[idx7, 'new_qmed_jul_ls'] = ((tributarios['new_qmed_jul_ls'].sum())+row7['vaz_qmed_increment_jul_ls'])
                bho.at[idx7, 'new_qmed_ago_ls'] = ((tributarios['new_qmed_ago_ls'].sum())+row7['vaz_qmed_increment_ago_ls'])
                bho.at[idx7, 'new_qmed_set_ls'] = ((tributarios['new_qmed_set_ls'].sum())+row7['vaz_qmed_increment_set_ls'])
                bho.at[idx7, 'new_qmed_out_ls'] = ((tributarios['new_qmed_out_ls'].sum())+row7['vaz_qmed_increment_out_ls'])
                bho.at[idx7, 'new_qmed_nov_ls'] = ((tributarios['new_qmed_nov_ls'].sum())+row7['vaz_qmed_increment_nov_ls'])
                bho.at[idx7, 'new_qmed_dez_ls'] = ((tributarios['new_qmed_dez_ls'].sum())+row7['vaz_qmed_increment_dez_ls'])


                bho.at[idx7, 'situacao_trecho'] = 'calculado'

    for idx,row in bho.loc[filtro_order8].iterrows():
        if bho.at[idx,'situacao_trecho']!= 'calculado':

            curso_principal_8_ordem = bho.loc[bho['cocursodag']==row['cocursodag']]
            curso_principal_8_ordem.sort_values(by='cobacia',ascending=False,inplace=True)

            for idx8, row8 in curso_principal_8_ordem.iterrows():
                tributarios = bho.loc[bho['nodestino'] == row8['noorigem']]

                bho.at[idx8, 'new_qmed_jan_ls'] = ((tributarios['new_qmed_jan_ls'].sum())+row8['vaz_qmed_increment_jan_ls'])
                bho.at[idx8, 'new_qmed_fev_ls'] = ((tributarios['new_qmed_fev_ls'].sum())+row8['vaz_qmed_increment_fev_ls'])
                bho.at[idx8, 'new_qmed_mar_ls'] = ((tributarios['new_qmed_mar_ls'].sum())+row8['vaz_qmed_increment_mar_ls'])
                bho.at[idx8, 'new_qmed_abr_ls'] = ((tributarios['new_qmed_abr_ls'].sum())+row8['vaz_qmed_increment_abr_ls'])
                bho.at[idx8, 'new_qmed_mai_ls'] = ((tributarios['new_qmed_mai_ls'].sum())+row8['vaz_qmed_increment_mai_ls'])
                bho.at[idx8, 'new_qmed_jun_ls'] = ((tributarios['new_qmed_jun_ls'].sum())+row8['vaz_qmed_increment_jun_ls'])
                bho.at[idx8, 'new_qmed_jul_ls'] = ((tributarios['new_qmed_jul_ls'].sum())+row8['vaz_qmed_increment_jul_ls'])
                bho.at[idx8, 'new_qmed_ago_ls'] = ((tributarios['new_qmed_ago_ls'].sum())+row8['vaz_qmed_increment_ago_ls'])
                bho.at[idx8, 'new_qmed_set_ls'] = ((tributarios['new_qmed_set_ls'].sum())+row8['vaz_qmed_increment_set_ls'])
                bho.at[idx8, 'new_qmed_out_ls'] = ((tributarios['new_qmed_out_ls'].sum())+row8['vaz_qmed_increment_out_ls'])
                bho.at[idx8, 'new_qmed_nov_ls'] = ((tributarios['new_qmed_nov_ls'].sum())+row8['vaz_qmed_increment_nov_ls'])
                bho.at[idx8, 'new_qmed_dez_ls'] = ((tributarios['new_qmed_dez_ls'].sum())+row8['vaz_qmed_increment_dez_ls'])


                bho.at[idx8, 'situacao_trecho'] = 'calculado'
    

    for idx,row in bho.loc[filtro_order9].iterrows():
        if bho.at[idx,'situacao_trecho']!= 'calculado':

            curso_principal_9_ordem = bho.loc[bho['cocursodag']==row['cocursodag']]
            curso_principal_9_ordem.sort_values(by='cobacia',ascending=False,inplace=True)

            for idx9, row9 in curso_principal_9_ordem.iterrows():
                tributarios = bho.loc[bho['nodestino'] == row9['noorigem']]

                bho.at[idx9, 'new_qmed_jan_ls'] = ((tributarios['new_qmed_jan_ls'].sum())+row9['vaz_qmed_increment_jan_ls'])
                bho.at[idx9, 'new_qmed_fev_ls'] = ((tributarios['new_qmed_fev_ls'].sum())+row9['vaz_qmed_increment_fev_ls'])
                bho.at[idx9, 'new_qmed_mar_ls'] = ((tributarios['new_qmed_mar_ls'].sum())+row9['vaz_qmed_increment_mar_ls'])
                bho.at[idx9, 'new_qmed_abr_ls'] = ((tributarios['new_qmed_abr_ls'].sum())+row9['vaz_qmed_increment_abr_ls'])
                bho.at[idx9, 'new_qmed_mai_ls'] = ((tributarios['new_qmed_mai_ls'].sum())+row9['vaz_qmed_increment_mai_ls'])
                bho.at[idx9, 'new_qmed_jun_ls'] = ((tributarios['new_qmed_jun_ls'].sum())+row9['vaz_qmed_increment_jun_ls'])
                bho.at[idx9, 'new_qmed_jul_ls'] = ((tributarios['new_qmed_jul_ls'].sum())+row9['vaz_qmed_increment_jul_ls'])
                bho.at[idx9, 'new_qmed_ago_ls'] = ((tributarios['new_qmed_ago_ls'].sum())+row9['vaz_qmed_increment_ago_ls'])
                bho.at[idx9, 'new_qmed_set_ls'] = ((tributarios['new_qmed_set_ls'].sum())+row9['vaz_qmed_increment_set_ls'])
                bho.at[idx9, 'new_qmed_out_ls'] = ((tributarios['new_qmed_out_ls'].sum())+row9['vaz_qmed_increment_out_ls'])
                bho.at[idx9, 'new_qmed_nov_ls'] = ((tributarios['new_qmed_nov_ls'].sum())+row9['vaz_qmed_increment_nov_ls'])
                bho.at[idx9, 'new_qmed_dez_ls'] = ((tributarios['new_qmed_dez_ls'].sum())+row9['vaz_qmed_increment_dez_ls'])


                bho.at[idx9, 'situacao_trecho'] = 'calculado'
        

    


    
            
              

    return bho

# %%
def corrige_bho_q95anual(bho):

    empty_gdf = pd.DataFrame()

   

    
    bho['q95_anual']  = bho['q95anualesp_inc_l/s/km2'] * bho['nuareamont'] 
   

    bho['vaz_q95_anual_incremental'] = bho['nuareacont'] * bho['q95anualesp_inc_l/s/km2']


    

    filtro_order1 = (bho['nustrahler'] == 1)
    filtro_order2 = (bho['nustrahler'] == 2)
    filtro_order3 = (bho['nustrahler'] == 3)
    filtro_order4 = (bho['nustrahler'] == 4)
    filtro_order5 = (bho['nustrahler'] == 5)
    filtro_order6 = (bho['nustrahler'] == 6)
    filtro_order7 = (bho['nustrahler'] == 7)
    filtro_order8 = (bho['nustrahler'] == 8)
    filtro_order9 = (bho['nustrahler'] == 9)


    bho.loc[filtro_order1,'situacao_trecho'] = 'calculado'
    
    primeira_ordem = bho.loc[filtro_order1]
    segunda_ordem = bho.loc[filtro_order2] 
    terceira_ordem = bho.loc[filtro_order3] 
    quarta_ordem = bho.loc[filtro_order4] 
    quinta_ordem = bho.loc[filtro_order5] 
    sexta_ordem = bho.loc[filtro_order6] 
    setima_ordem = bho.loc[filtro_order7] 



    bho['new_q95_anual_ls'] = bho['q95_anual']

    

    

    
    for idx,row in bho.loc[filtro_order2].iterrows():
        if bho.at[idx,'situacao_trecho']!= 'calculado':


            curso_principal_2_ordem = bho.loc[bho['cocursodag']==row['cocursodag']]
            curso_principal_2_ordem.sort_values(by='cobacia',ascending=False,inplace=True)

            for idx2, row2 in curso_principal_2_ordem.iterrows():
                tributarios = bho.loc[bho['nodestino'] == row2['noorigem']]

                bho.at[idx2, 'new_q95_anual_ls'] = ((tributarios['new_q95_anual_ls'].sum())+row2['vaz_q95_anual_incremental'])
                


                bho.at[idx2, 'situacao_trecho'] = 'calculado'
    
    for idx,row in bho.loc[filtro_order3].iterrows():
        if bho.at[idx,'situacao_trecho']!= 'calculado':

            curso_principal_3_ordem = bho.loc[bho['cocursodag']==row['cocursodag']]
            curso_principal_3_ordem.sort_values(by='cobacia',ascending=False,inplace=True)

            for idx3, row3 in curso_principal_3_ordem.iterrows():
                tributarios = bho.loc[bho['nodestino'] == row3['noorigem']]

                bho.at[idx3, 'new_q95_anual_ls'] = ((tributarios['new_q95_anual_ls'].sum())+row3['vaz_q95_anual_incremental'])
                

                bho.at[idx3, 'situacao_trecho'] = 'calculado'
    
    for idx,row in bho.loc[filtro_order4].iterrows():
        if bho.at[idx,'situacao_trecho']!= 'calculado':

            curso_principal_4_ordem = bho.loc[bho['cocursodag']==row['cocursodag']]
            curso_principal_4_ordem.sort_values(by='cobacia',ascending=False,inplace=True)

            for idx4, row4 in curso_principal_4_ordem.iterrows():
                tributarios = bho.loc[bho['nodestino'] == row4['noorigem']]

                bho.at[idx4, 'new_q95_anual_ls'] = ((tributarios['new_q95_anual_ls'].sum())+row4['vaz_q95_anual_incremental'])



                bho.at[idx4, 'situacao_trecho'] = 'calculado'
    
    for idx,row in bho.loc[filtro_order5].iterrows():
        if bho.at[idx,'situacao_trecho']!= 'calculado':

            curso_principal_5_ordem = bho.loc[bho['cocursodag']==row['cocursodag']]
            curso_principal_5_ordem.sort_values(by='cobacia',ascending=False,inplace=True)

            for idx5, row5 in curso_principal_5_ordem.iterrows():
                tributarios = bho.loc[bho['nodestino'] == row5['noorigem']]

                bho.at[idx5, 'new_q95_anual_ls'] = ((tributarios['new_q95_anual_ls'].sum())+row5['vaz_q95_anual_incremental'])



                bho.at[idx5, 'situacao_trecho'] = 'calculado'

    for idx,row in bho.loc[filtro_order6].iterrows():
        if bho.at[idx,'situacao_trecho']!= 'calculado':

            curso_principal_6_ordem = bho.loc[bho['cocursodag']==row['cocursodag']]
            curso_principal_6_ordem.sort_values(by='cobacia',ascending=False,inplace=True)

            for idx5, row6 in curso_principal_6_ordem.iterrows():
                tributarios = bho.loc[bho['nodestino'] == row6['noorigem']]

                bho.at[idx5, 'new_q95_anual_ls'] = ((tributarios['new_q95_anual_ls'].sum())+row6['vaz_q95_anual_incremental'])



                bho.at[idx5, 'situacao_trecho'] = 'calculado'
    

    for idx,row in bho.loc[filtro_order7].iterrows():
        if bho.at[idx,'situacao_trecho']!= 'calculado':

            curso_principal_7_ordem = bho.loc[bho['cocursodag']==row['cocursodag']]
            curso_principal_7_ordem.sort_values(by='cobacia',ascending=False,inplace=True)

            for idx7, row7 in curso_principal_7_ordem.iterrows():
                tributarios = bho.loc[bho['nodestino'] == row7['noorigem']]

                bho.at[idx7, 'new_q95_anual_ls'] = ((tributarios['new_q95_anual_ls'].sum())+row7['vaz_q95_anual_incremental'])



                bho.at[idx7, 'situacao_trecho'] = 'calculado'

    for idx,row in bho.loc[filtro_order8].iterrows():
        if bho.at[idx,'situacao_trecho']!= 'calculado':

            curso_principal_8_ordem = bho.loc[bho['cocursodag']==row['cocursodag']]
            curso_principal_8_ordem.sort_values(by='cobacia',ascending=False,inplace=True)

            for idx8, row8 in curso_principal_8_ordem.iterrows():
                tributarios = bho.loc[bho['nodestino'] == row8['noorigem']]

                bho.at[idx8, 'new_q95_anual_ls'] = ((tributarios['new_q95_anual_ls'].sum())+row8['vaz_q95_anual_incremental'])


                bho.at[idx8, 'situacao_trecho'] = 'calculado'
    

    for idx,row in bho.loc[filtro_order9].iterrows():
        if bho.at[idx,'situacao_trecho']!= 'calculado':

            curso_principal_9_ordem = bho.loc[bho['cocursodag']==row['cocursodag']]
            curso_principal_9_ordem.sort_values(by='cobacia',ascending=False,inplace=True)

            for idx9, row9 in curso_principal_9_ordem.iterrows():
                tributarios = bho.loc[bho['nodestino'] == row9['noorigem']]

                bho.at[idx9, 'new_q95_anual_ls'] = ((tributarios['new_q95_anual_ls'].sum())+row9['vaz_q95_anual_incremental'])



                bho.at[idx9, 'situacao_trecho'] = 'calculado'
        


    return bho

# %%
union = union_areas_incrementais_centros_superf(bho_centros_superficie_filtered,areas_incrementais_estacoes)

# %%
union_q95 = corrige_bho_q95(union)
# Out:
# C:\Users\matheus.cgomes\AppData\Local\Temp\ipykernel_4808\2790579496.py:80: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   curso_principal_2_ordem.sort_values(by='cobacia',ascending=False,inplace=True)
# C:\Users\matheus.cgomes\AppData\Local\Temp\ipykernel_4808\2790579496.py:105: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   curso_principal_3_ordem.sort_values(by='cobacia',ascending=False,inplace=True)
# C:\Users\matheus.cgomes\AppData\Local\Temp\ipykernel_4808\2790579496.py:155: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %%
union_q95.drop('situacao_trecho',inplace=True,axis=1)

# %%
union_qmed = corrige_bho_qmed(union_q95)
# Out:
# C:\Users\matheus.cgomes\AppData\Local\Temp\ipykernel_4808\227931449.py:80: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   curso_principal_2_ordem.sort_values(by='cobacia',ascending=False,inplace=True)
# C:\Users\matheus.cgomes\AppData\Local\Temp\ipykernel_4808\227931449.py:105: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   curso_principal_3_ordem.sort_values(by='cobacia',ascending=False,inplace=True)
# C:\Users\matheus.cgomes\AppData\Local\Temp\ipykernel_4808\227931449.py:155: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %%
union_qmed.drop('situacao_trecho',inplace=True,axis=1)

unionq95anual = corrige_bho_q95anual(union_qmed)
# Out:
# C:\Users\matheus.cgomes\AppData\Local\Temp\ipykernel_4808\1921791981.py:51: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   curso_principal_2_ordem.sort_values(by='cobacia',ascending=False,inplace=True)
# C:\Users\matheus.cgomes\AppData\Local\Temp\ipykernel_4808\1921791981.py:66: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   curso_principal_3_ordem.sort_values(by='cobacia',ascending=False,inplace=True)
# C:\Users\matheus.cgomes\AppData\Local\Temp\ipykernel_4808\1921791981.py:95: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %%
#unionq95anual.to_csv('D:\\matheus.cgomes\\Documentos\\GitHub\\gis_automations\\data\\26-06-2024\\bho_q95_qmed_q95anual_correc_26-06-2024.csv')
#unionq95anual.to_file('D:\\matheus.cgomes\\Documentos\\GitHub\\gis_automations\\data\\26-06-2024\\bho_q95_qmed_q95anual_correc_26-06-2024.gpkg')
