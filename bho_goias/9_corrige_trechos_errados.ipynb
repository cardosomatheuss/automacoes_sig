# %%
import pandas as pd 
import geopandas as gpd

# %%
bho = gpd.read_file('D:\\matheus.cgomes\\Documentos\\GitHub\\gis_automations\\data\\26-06-2024\\bho_q95_qmed_q95anual_saomarcosok_26-06-2024.gpkg')

# %%
#Meia Ponte

seleciona_trechos4 = ((bho['cobacia']<= '86952599') & (bho['cocursodag']=='86952'))

bho.loc[seleciona_trechos4,'new_q95_jan_ls'] = bho['new_q95_jan_ls'] + 43.5940565414967
bho.loc[seleciona_trechos4,'new_q95_fev_ls'] = bho['new_q95_fev_ls'] + 25.1719733970676
bho.loc[seleciona_trechos4,'new_q95_mar_ls'] = bho['new_q95_mar_ls'] - 45.567851164109
bho.loc[seleciona_trechos4,'new_q95_abr_ls'] = bho['new_q95_abr_ls'] + 140.066314701224
bho.loc[seleciona_trechos4,'new_q95_mai_ls'] = bho['new_q95_mai_ls'] + 51.0262461698621
bho.loc[seleciona_trechos4,'new_q95_jun_ls'] = bho['new_q95_jun_ls'] + 30.337954384664
bho.loc[seleciona_trechos4,'new_q95_jul_ls'] = bho['new_q95_jul_ls'] + 9.64966259946232
bho.loc[seleciona_trechos4,'new_q95_ago_ls'] = bho['new_q95_ago_ls'] - 8.84552404950409
bho.loc[seleciona_trechos4,'new_q95_set_ls'] = bho['new_q95_set_ls'] - 62.7959104010242
bho.loc[seleciona_trechos4,'new_q95_out_ls'] = bho['new_q95_out_ls'] - 71.3977561020547
bho.loc[seleciona_trechos4,'new_q95_nov_ls'] = bho['new_q95_nov_ls'] - 49.5885439138801
bho.loc[seleciona_trechos4,'new_q95_dez_ls'] = bho['new_q95_dez_ls'] + 19.835417565555

bho.loc[seleciona_trechos4,'new_qmed_jan_ls'] = bho['new_qmed_jan_ls'] + 233.687536183861
bho.loc[seleciona_trechos4,'new_qmed_fev_ls'] = bho['new_qmed_fev_ls'] + 336.032442541735 
bho.loc[seleciona_trechos4,'new_qmed_mar_ls'] = bho['new_qmed_mar_ls'] + 351.8715351923754
bho.loc[seleciona_trechos4,'new_qmed_abr_ls'] = bho['new_qmed_abr_ls'] + 344.31750638978
bho.loc[seleciona_trechos4,'new_qmed_mai_ls'] = bho['new_qmed_mai_ls'] + 254.156517455442
bho.loc[seleciona_trechos4,'new_qmed_jun_ls'] = bho['new_qmed_jun_ls'] + 229.008911893223
bho.loc[seleciona_trechos4,'new_qmed_jul_ls'] = bho['new_qmed_jul_ls'] + 187.681063992502
bho.loc[seleciona_trechos4,'new_qmed_ago_ls'] = bho['new_qmed_ago_ls'] + 148.83873524619
bho.loc[seleciona_trechos4,'new_qmed_set_ls'] = bho['new_qmed_set_ls'] + 142.429994681403
bho.loc[seleciona_trechos4,'new_qmed_out_ls'] = bho['new_qmed_out_ls'] + 135.022172887875
bho.loc[seleciona_trechos4,'new_qmed_nov_ls'] = bho['new_qmed_nov_ls'] + 194.552793419389
bho.loc[seleciona_trechos4,'new_qmed_dez_ls'] = bho['new_qmed_dez_ls'] + 211.293495959369

bho.loc[seleciona_trechos4,'new_q95_anual_ls'] = bho['new_q95_anual_ls'] - 10.8193186721201

# %%
#Nascente Araguaia

seleciona_trechos5 = ((bho['cobacia']<= '699999481') & (bho['cocursodag']=='69999948'))

bho.loc[seleciona_trechos5,'new_q95_jan_ls'] = bho['new_q95_jan_ls'] - 4.37976955905356
bho.loc[seleciona_trechos5,'new_q95_fev_ls'] = bho['new_q95_fev_ls'] - 5.09756512567622
bho.loc[seleciona_trechos5,'new_q95_mar_ls'] = bho['new_q95_mar_ls'] - 4.85424459461768
bho.loc[seleciona_trechos5,'new_q95_abr_ls'] = bho['new_q95_abr_ls'] - 4.14861505454795
bho.loc[seleciona_trechos5,'new_q95_mai_ls'] = bho['new_q95_mai_ls'] - 3.83229836417186
bho.loc[seleciona_trechos5,'new_q95_jun_ls'] = bho['new_q95_jun_ls'] - 3.51598167379577
bho.loc[seleciona_trechos5,'new_q95_jul_ls'] = bho['new_q95_jul_ls'] - 3.40648743481943
bho.loc[seleciona_trechos5,'new_q95_ago_ls'] = bho['new_q95_ago_ls'] - 3.24832908963138
bho.loc[seleciona_trechos5,'new_q95_set_ls'] = bho['new_q95_set_ls'] - 3.30915922239602
bho.loc[seleciona_trechos5,'new_q95_out_ls'] = bho['new_q95_out_ls'] - 3.83229836417186
bho.loc[seleciona_trechos5,'new_q95_nov_ls'] = bho['new_q95_nov_ls'] - 3.92962657659527
bho.loc[seleciona_trechos5,'new_q95_dez_ls'] = bho['new_q95_dez_ls'] - 4.37976955905356

bho.loc[seleciona_trechos5,'new_qmed_jan_ls'] = bho['new_qmed_jan_ls'] - 7.60376659557909
bho.loc[seleciona_trechos5,'new_qmed_fev_ls'] = bho['new_qmed_fev_ls'] - 7.8349211000847 
bho.loc[seleciona_trechos5,'new_qmed_mar_ls'] = bho['new_qmed_mar_ls'] - 7.81058904697883
bho.loc[seleciona_trechos5,'new_qmed_abr_ls'] = bho['new_qmed_abr_ls'] - 6.70348063066253
bho.loc[seleciona_trechos5,'new_qmed_mai_ls'] = bho['new_qmed_mai_ls'] - 5.8275267188518
bho.loc[seleciona_trechos5,'new_qmed_jun_ls'] = bho['new_qmed_jun_ls'] - 5.29222155052305
bho.loc[seleciona_trechos5,'new_qmed_jul_ls'] = bho['new_qmed_jul_ls'] - 4.87857664772354
bho.loc[seleciona_trechos5,'new_qmed_ago_ls'] = bho['new_qmed_ago_ls'] - 4.69608624942965
bho.loc[seleciona_trechos5,'new_qmed_set_ls'] = bho['new_qmed_set_ls'] - 4.87857664772354
bho.loc[seleciona_trechos5,'new_qmed_out_ls'] = bho['new_qmed_out_ls'] - 5.37738373639353
bho.loc[seleciona_trechos5,'new_qmed_nov_ls'] = bho['new_qmed_nov_ls'] - 6.10734532956913
bho.loc[seleciona_trechos5,'new_qmed_dez_ls'] = bho['new_qmed_dez_ls'] - 6.98329924137983

bho.loc[seleciona_trechos5,'new_q95_anual_ls'] = bho['new_q95_anual_ls'] - 3.72280412519553

# %%
#Rio Caiapó

seleciona_trechos6 = ((bho['cobacia']<= '696199') & (bho['cocursodag']=='696'))


bho.loc[seleciona_trechos6,'new_q95_jan_ls'] = bho['new_q95_jan_ls'] + 907.847644194306
bho.loc[seleciona_trechos6,'new_q95_fev_ls'] = bho['new_q95_fev_ls'] - 3273.80352853273
bho.loc[seleciona_trechos6,'new_q95_mar_ls'] = bho['new_q95_mar_ls'] + 2234.44854225378
bho.loc[seleciona_trechos6,'new_q95_abr_ls'] = bho['new_q95_abr_ls'] + 1410.82205810653
bho.loc[seleciona_trechos6,'new_q95_mai_ls'] = bho['new_q95_mai_ls'] + 2083.65031993489
bho.loc[seleciona_trechos6,'new_q95_jun_ls'] = bho['new_q95_jun_ls'] + 1041.7781090400
bho.loc[seleciona_trechos6,'new_q95_jul_ls'] = bho['new_q95_jul_ls'] + 223.985939890485
bho.loc[seleciona_trechos6,'new_q95_ago_ls'] = bho['new_q95_ago_ls'] - 69.8706271898664
bho.loc[seleciona_trechos6,'new_q95_set_ls'] = bho['new_q95_set_ls'] - 847.140185115684
bho.loc[seleciona_trechos6,'new_q95_out_ls'] = bho['new_q95_out_ls'] - 1052.64687326959
bho.loc[seleciona_trechos6,'new_q95_nov_ls'] = bho['new_q95_nov_ls'] - 1570.23060013973
bho.loc[seleciona_trechos6,'new_q95_dez_ls'] = bho['new_q95_dez_ls'] - 2573.61515242091

bho.loc[seleciona_trechos6,'new_qmed_jan_ls'] = bho['new_qmed_jan_ls'] + 18904.592120281
bho.loc[seleciona_trechos6,'new_qmed_fev_ls'] = bho['new_qmed_fev_ls'] + 18871.8917257376 
bho.loc[seleciona_trechos6,'new_qmed_mar_ls'] = bho['new_qmed_mar_ls'] + 19215.8340050358
bho.loc[seleciona_trechos6,'new_qmed_abr_ls'] = bho['new_qmed_abr_ls'] + 9608.50513911052
bho.loc[seleciona_trechos6,'new_qmed_mai_ls'] = bho['new_qmed_mai_ls'] + 3321.79547448133
bho.loc[seleciona_trechos6,'new_qmed_jun_ls'] = bho['new_qmed_jun_ls'] + 2300.3198406146
bho.loc[seleciona_trechos6,'new_qmed_jul_ls'] = bho['new_qmed_jul_ls'] + 1134.60958880142
bho.loc[seleciona_trechos6,'new_qmed_ago_ls'] = bho['new_qmed_ago_ls'] + 338.107964300616
bho.loc[seleciona_trechos6,'new_qmed_set_ls'] = bho['new_qmed_set_ls'] + 61.9425459228733
bho.loc[seleciona_trechos6,'new_qmed_out_ls'] = bho['new_qmed_out_ls'] + 25.8074336792342
bho.loc[seleciona_trechos6,'new_qmed_nov_ls'] = bho['new_qmed_nov_ls'] + 2184.57455920916
bho.loc[seleciona_trechos6,'new_qmed_dez_ls'] = bho['new_qmed_dez_ls'] + 5878.30761479217

bho.loc[seleciona_trechos6,'new_q95_anual_ls'] = bho['new_q95_anual_ls'] -1139.99691998879

# %%
#Rio Vermelho

seleciona_trechos7 = ((bho['cobacia']<= '6954739') & (bho['cocursodag']=='6954'))


bho.loc[seleciona_trechos7,'new_q95_jan_ls'] = bho['new_q95_jan_ls'] + 62.5727405992493
bho.loc[seleciona_trechos7,'new_q95_fev_ls'] = bho['new_q95_fev_ls'] - 610.937419122743
bho.loc[seleciona_trechos7,'new_q95_mar_ls'] = bho['new_q95_mar_ls'] - 685.239582921884
bho.loc[seleciona_trechos7,'new_q95_abr_ls'] = bho['new_q95_abr_ls'] - 90.8989234972541
bho.loc[seleciona_trechos7,'new_q95_mai_ls'] = bho['new_q95_mai_ls'] + 49.3486235140781
bho.loc[seleciona_trechos7,'new_q95_jun_ls'] = bho['new_q95_jun_ls'] + 119.29920233145
bho.loc[seleciona_trechos7,'new_q95_jul_ls'] = bho['new_q95_jul_ls'] - 21.9424347400932
bho.loc[seleciona_trechos7,'new_q95_ago_ls'] = bho['new_q95_ago_ls'] + 65.9804236549261
bho.loc[seleciona_trechos7,'new_q95_set_ls'] = bho['new_q95_set_ls'] - 11.446362123445
bho.loc[seleciona_trechos7,'new_q95_out_ls'] = bho['new_q95_out_ls'] + 13.2441923388192
bho.loc[seleciona_trechos7,'new_q95_nov_ls'] = bho['new_q95_nov_ls'] + 78.160262545764
bho.loc[seleciona_trechos7,'new_q95_dez_ls'] = bho['new_q95_dez_ls'] + 128.661570623878

bho.loc[seleciona_trechos7,'new_qmed_jan_ls'] = bho['new_qmed_jan_ls'] - 956.728188148612
bho.loc[seleciona_trechos7,'new_qmed_fev_ls'] = bho['new_qmed_fev_ls'] - 655.033626273158 
bho.loc[seleciona_trechos7,'new_qmed_mar_ls'] = bho['new_qmed_mar_ls'] - 659.203803962882
bho.loc[seleciona_trechos7,'new_qmed_abr_ls'] = bho['new_qmed_abr_ls'] + 196.023901739041
bho.loc[seleciona_trechos7,'new_qmed_mai_ls'] = bho['new_qmed_mai_ls'] + 480.6690981977663
bho.loc[seleciona_trechos7,'new_qmed_jun_ls'] = bho['new_qmed_jun_ls'] + 507.79259089992
bho.loc[seleciona_trechos7,'new_qmed_jul_ls'] = bho['new_qmed_jul_ls'] + 493.10298029841
bho.loc[seleciona_trechos7,'new_qmed_ago_ls'] = bho['new_qmed_ago_ls'] + 463.565164591566
bho.loc[seleciona_trechos7,'new_qmed_set_ls'] = bho['new_qmed_set_ls'] + 500.13278661919
bho.loc[seleciona_trechos7,'new_qmed_out_ls'] = bho['new_qmed_out_ls'] + 592.794317386779
bho.loc[seleciona_trechos7,'new_qmed_nov_ls'] = bho['new_qmed_nov_ls'] + 561.701947038324
bho.loc[seleciona_trechos7,'new_qmed_dez_ls'] = bho['new_qmed_dez_ls'] + 1372.6162678458

bho.loc[seleciona_trechos7,'new_q95_anual_ls'] = bho['new_q95_anual_ls'] +50.927450962379

# %%
bho.to_file('D:\\matheus.cgomes\\Documentos\\GitHub\\gis_automations\\data\\26-06-2024\\bho_q95_qmed_q95anual_saomarcosok_26-06-2024_correc.gpkg')
