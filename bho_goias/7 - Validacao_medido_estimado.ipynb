# %%
import pandas as pd
import geopandas as gpd

# %%
estacoes = gpd.read_file('D:\\matheus.cgomes\\Documentos\\GitHub\\gis_automations\\data\\68_estacoes_vazoes.gpkg')
trechos = gpd.read_file('D:\\matheus.cgomes\\Documentos\\GitHub\\gis_automations\\data\\17-06-2024\\bho_q95_qmed_q95anual_polygons_17-06-2024.gpkg')

# %%
sjoin_estacoes = gpd.sjoin(estacoes,trechos,how='inner')

# %%
sjoin_estacoes.info(verbose=True)
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# Index: 64 entries, 0 to 66
# Data columns (total 110 columns):
#  #    Column           Dtype
# ---   ------           -----
#  0    id_left          int64
#  1    codigo           object
#  2    codalt           object
#  3    nome             object
#  4    rio              object
#  5    adkm2            object
#  6    anoinicio        object
#  7    anofim           object
#  8    anototal         object
#  9    q95_jan_(m³/s)   object
#  10   q95_fev_(m³/s)   object
#  11   q95_mar_(m³/s)   object
#  12   q95_abr_(m³/s)   object
#  13   q95_mai_(m³/s)   object
#  14   q95_jun_(m³/s)   object
#  15   q95_jul_(m³/s)   object
#  16   q95_ago_(m³/s)   object
#  17   q95_set_(m³/s)   object
#  18   q95_out_(m³/s)   object
#  19   q95_nov_(m³/s)   object
#  20   q95_dez_(m³/s)   object
#  21   qmed_jan_(m³/s)  object
#  22   qmed_fev_(m³/s)  object
#  23   qmed_mar_(m³/s)  object
#  24   qmed_abr_(m³/s)  object
#  25   qmed_mai_(m³/s)  object
#  26   qmed_jun_(m³/s)  object
#  27   qmed_jul_(m³/s)  object
#  28   qmed_ago_(m³/s)  object
#  29   qmed_set_(m³/s)  object
#  30   qmed_out_(m³/s)  object
#  31   qmed_nov_(m³/s)  object
#  32   qmed_dez_(m³/s)  object
#  33   geometry         geometry
#  34   index_right      int64
#  35   id_right         float64
#  36   cobacia          object
#  37   cocursodag       object
#  38   noorigem         float64
#  39   nodestino        float64
#  40   nucomptrec       float64
#  41   nudistbact       float64
#  42   nudistcdag       float64
#  43   nuareacont       float64
#  44   nuareamont       float64
#  45   nogenerico       object
#  46   noligacao        object
#  47   noespecif        object
#  48   noriocomp        object
#  49   nooriginal       object
#  50   cocdadesag       object
#  51   nutrjus          float64
#  52   nudistbacc       float64
#  53   nuareabacc       float64
#  54   nuordemcda       float64
#  55   nucompcda        float64
#  56   nunivotto        float64
#  57   nunivotcda       float64
#  58   nustrahler       float64
#  59   dedominial       object
#  60   dsversao         object
#  61   cobacia_jus      object
#  62   q95_jan          float64
#  63   q95_fev          float64
#  64   q95_mar          float64
#  65   q95_abr          float64
#  66   q95_mai          float64
#  67   q95_jun          float64
#  68   q95_jul          float64
#  69   q95_ago          float64
#  70   q95_set          float64
#  71   q95_out          float64
#  72   q95_nov          float64
#  73   q95_dez          float64
#  74   qmed_jan         float64
#  75   qmed_fev         float64
#  76   qmed_mar         float64
#  77   qmed_abr         float64
#  78   qmed_mai         float64
#  79   qmed_jun         float64
#  80   qmed_jul         float64
#  81   qmed_ago         float64
#  82   qmed_set         float64
#  83   qmed_out         float64
#  84   qmed_nov         float64
#  85   qmed_dez         float64
#  86   q95_esp_jan      float64
#  87   q95_esp_fev      float64
#  88   q95_esp_mar      float64
#  89   q95_esp_abr      float64
#  90   q95_esp_mai      float64
#  91   q95_esp_jun      float64
#  92   q95_esp_jul      float64
#  93   q95_esp_ago      float64
#  94   q95_esp_set      float64
#  95   q95_esp_out      float64
#  96   q95_esp_nov      float64
#  97   q95_esp_dez      float64
#  98   qmed_esp_jan     float64
#  99   qmed_esp_fev     float64
#  100  qmed_esp_mar     float64
#  101  qmed_esp_abr     float64
#  102  qmed_esp_mai     float64
#  103  qmed_esp_jun     float64
#  104  qmed_esp_jul     float64
#  105  qmed_esp_ago     float64
#  106  qmed_esp_set     float64
#  107  qmed_esp_out     float64
#  108  qmed_esp_nov     float64
#  109  qmed_esp_dez     float64
# dtypes: float64(64), geometry(1), int64(2), object(43)
# memory usage: 55.5+ KB

# %%
columns_to_float = ['q95_jan_(m³/s)', 'q95_fev_(m³/s)', 'q95_mar_(m³/s)',
       'q95_abr_(m³/s)', 'q95_mai_(m³/s)', 'q95_jun_(m³/s)', 'q95_jul_(m³/s)',
       'q95_ago_(m³/s)', 'q95_set_(m³/s)', 'q95_out_(m³/s)', 'q95_nov_(m³/s)',
       'q95_dez_(m³/s)', 'qmed_jan_(m³/s)', 'qmed_fev_(m³/s)',
       'qmed_mar_(m³/s)', 'qmed_abr_(m³/s)', 'qmed_mai_(m³/s)',
       'qmed_jun_(m³/s)', 'qmed_jul_(m³/s)', 'qmed_ago_(m³/s)',
       'qmed_set_(m³/s)', 'qmed_out_(m³/s)', 'qmed_nov_(m³/s)',
       'qmed_dez_(m³/s)']
for column in columns_to_float:
    sjoin_estacoes[column] = sjoin_estacoes[column].str.replace(',','.').astype(float)

sjoin_estacoes['adkm2'] = sjoin_estacoes['adkm2'].astype(int)

# %%
sjoin_estacoes['q95_jan_simulado'] = (sjoin_estacoes['q95_jan']/sjoin_estacoes['nuareamont']) * sjoin_estacoes['adkm2']
sjoin_estacoes['q95_fev_simulado'] = (sjoin_estacoes['q95_fev']/sjoin_estacoes['nuareamont']) * sjoin_estacoes['adkm2']
sjoin_estacoes['q95_mar_simulado'] = (sjoin_estacoes['q95_mar']/sjoin_estacoes['nuareamont']) * sjoin_estacoes['adkm2']
sjoin_estacoes['q95_abr_simulado'] = (sjoin_estacoes['q95_abr']/sjoin_estacoes['nuareamont']) * sjoin_estacoes['adkm2']
sjoin_estacoes['q95_mai_simulado'] = (sjoin_estacoes['q95_mai']/sjoin_estacoes['nuareamont']) * sjoin_estacoes['adkm2']
sjoin_estacoes['q95_jun_simulado'] = (sjoin_estacoes['q95_jun']/sjoin_estacoes['nuareamont']) * sjoin_estacoes['adkm2']
sjoin_estacoes['q95_jul_simulado'] = (sjoin_estacoes['q95_jul']/sjoin_estacoes['nuareamont']) * sjoin_estacoes['adkm2']
sjoin_estacoes['q95_ago_simulado'] = (sjoin_estacoes['q95_ago']/sjoin_estacoes['nuareamont']) * sjoin_estacoes['adkm2']
sjoin_estacoes['q95_set_simulado'] = (sjoin_estacoes['q95_set']/sjoin_estacoes['nuareamont']) * sjoin_estacoes['adkm2']
sjoin_estacoes['q95_out_simulado'] = (sjoin_estacoes['q95_out']/sjoin_estacoes['nuareamont']) * sjoin_estacoes['adkm2']
sjoin_estacoes['q95_nov_simulado'] = (sjoin_estacoes['q95_nov']/sjoin_estacoes['nuareamont']) * sjoin_estacoes['adkm2']
sjoin_estacoes['q95_dez_simulado'] = (sjoin_estacoes['q95_dez']/sjoin_estacoes['nuareamont']) * sjoin_estacoes['adkm2']


sjoin_estacoes['qmed_jan_simulado'] = (sjoin_estacoes['qmed_jan']/sjoin_estacoes['nuareamont']) * sjoin_estacoes['adkm2']
sjoin_estacoes['qmed_fev_simulado'] = (sjoin_estacoes['qmed_fev']/sjoin_estacoes['nuareamont']) * sjoin_estacoes['adkm2']
sjoin_estacoes['qmed_mar_simulado'] = (sjoin_estacoes['qmed_mar']/sjoin_estacoes['nuareamont']) * sjoin_estacoes['adkm2']
sjoin_estacoes['qmed_abr_simulado'] = (sjoin_estacoes['qmed_abr']/sjoin_estacoes['nuareamont']) * sjoin_estacoes['adkm2']
sjoin_estacoes['qmed_mai_simulado'] = (sjoin_estacoes['qmed_mai']/sjoin_estacoes['nuareamont']) * sjoin_estacoes['adkm2']
sjoin_estacoes['qmed_jun_simulado'] = (sjoin_estacoes['qmed_jun']/sjoin_estacoes['nuareamont']) * sjoin_estacoes['adkm2']
sjoin_estacoes['qmed_jul_simulado'] = (sjoin_estacoes['qmed_jul']/sjoin_estacoes['nuareamont']) * sjoin_estacoes['adkm2']
sjoin_estacoes['qmed_ago_simulado'] = (sjoin_estacoes['qmed_ago']/sjoin_estacoes['nuareamont']) * sjoin_estacoes['adkm2']
sjoin_estacoes['qmed_set_simulado'] = (sjoin_estacoes['qmed_set']/sjoin_estacoes['nuareamont']) * sjoin_estacoes['adkm2']
sjoin_estacoes['qmed_out_simulado'] = (sjoin_estacoes['qmed_out']/sjoin_estacoes['nuareamont']) * sjoin_estacoes['adkm2']
sjoin_estacoes['qmed_nov_simulado'] = (sjoin_estacoes['qmed_nov']/sjoin_estacoes['nuareamont']) * sjoin_estacoes['adkm2']
sjoin_estacoes['qmed_dez_simulado'] = (sjoin_estacoes['qmed_dez']/sjoin_estacoes['nuareamont']) * sjoin_estacoes['adkm2']

# %%
sjoin_estacoes['percent_dif_q95_jan'] = (((sjoin_estacoes['q95_jan_simulado']-(sjoin_estacoes['q95_jan_(m³/s)']*1000))/(sjoin_estacoes['q95_jan_(m³/s)']*1000))*100).round(2)
sjoin_estacoes['percent_dif_q95_fev'] = (((sjoin_estacoes['q95_fev_simulado']-(sjoin_estacoes['q95_fev_(m³/s)']*1000))/(sjoin_estacoes['q95_fev_(m³/s)']*1000))*100).round(2)
sjoin_estacoes['percent_dif_q95_mar'] = (((sjoin_estacoes['q95_mar_simulado']-(sjoin_estacoes['q95_mar_(m³/s)']*1000))/(sjoin_estacoes['q95_mar_(m³/s)']*1000))*100).round(2)
sjoin_estacoes['percent_dif_q95_abr'] = (((sjoin_estacoes['q95_abr_simulado']-(sjoin_estacoes['q95_abr_(m³/s)']*1000))/(sjoin_estacoes['q95_abr_(m³/s)']*1000))*100).round(2)
sjoin_estacoes['percent_dif_q95_mai'] = (((sjoin_estacoes['q95_mai_simulado']-(sjoin_estacoes['q95_mai_(m³/s)']*1000))/(sjoin_estacoes['q95_mai_(m³/s)']*1000))*100).round(2)
sjoin_estacoes['percent_dif_q95_jun'] = (((sjoin_estacoes['q95_jun_simulado']-(sjoin_estacoes['q95_jun_(m³/s)']*1000))/(sjoin_estacoes['q95_jun_(m³/s)']*1000))*100).round(2)
sjoin_estacoes['percent_dif_q95_jul'] = (((sjoin_estacoes['q95_jul_simulado']-(sjoin_estacoes['q95_jul_(m³/s)']*1000))/(sjoin_estacoes['q95_jul_(m³/s)']*1000))*100).round(2)
sjoin_estacoes['percent_dif_q95_ago'] = (((sjoin_estacoes['q95_ago_simulado']-(sjoin_estacoes['q95_ago_(m³/s)']*1000))/(sjoin_estacoes['q95_ago_(m³/s)']*1000))*100).round(2)
sjoin_estacoes['percent_dif_q95_set'] = (((sjoin_estacoes['q95_set_simulado']-(sjoin_estacoes['q95_set_(m³/s)']*1000))/(sjoin_estacoes['q95_set_(m³/s)']*1000))*100).round(2)
sjoin_estacoes['percent_dif_q95_out'] = (((sjoin_estacoes['q95_out_simulado']-(sjoin_estacoes['q95_out_(m³/s)']*1000))/(sjoin_estacoes['q95_out_(m³/s)']*1000))*100).round(2)
sjoin_estacoes['percent_dif_q95_nov'] = (((sjoin_estacoes['q95_nov_simulado']-(sjoin_estacoes['q95_nov_(m³/s)']*1000))/(sjoin_estacoes['q95_nov_(m³/s)']*1000))*100).round(2)
sjoin_estacoes['percent_dif_q95_dez'] = (((sjoin_estacoes['q95_dez_simulado']-(sjoin_estacoes['q95_dez_(m³/s)']*1000))/(sjoin_estacoes['q95_dez_(m³/s)']*1000))*100).round(2)

sjoin_estacoes['percent_medio_dif_q95'] = ((sjoin_estacoes['percent_dif_q95_jan'].abs()+sjoin_estacoes['percent_dif_q95_fev'].abs()+sjoin_estacoes['percent_dif_q95_mar'].abs()+
                                           sjoin_estacoes['percent_dif_q95_abr'].abs()+sjoin_estacoes['percent_dif_q95_mai'].abs()+sjoin_estacoes['percent_dif_q95_jun'].abs()+
                                           sjoin_estacoes['percent_dif_q95_jul'].abs()+sjoin_estacoes['percent_dif_q95_ago'].abs()+sjoin_estacoes['percent_dif_q95_set'].abs()+
                                           sjoin_estacoes['percent_dif_q95_out'].abs()+sjoin_estacoes['percent_dif_q95_nov'].abs()+sjoin_estacoes['percent_dif_q95_dez'].abs())/12).round(2)




sjoin_estacoes['percent_dif_qmed_jan'] = (((sjoin_estacoes['qmed_jan_simulado']-(sjoin_estacoes['qmed_jan_(m³/s)']*1000))/(sjoin_estacoes['qmed_jan_(m³/s)']*1000))*100).round(2)
sjoin_estacoes['percent_dif_qmed_fev'] = (((sjoin_estacoes['qmed_fev_simulado']-(sjoin_estacoes['qmed_fev_(m³/s)']*1000))/(sjoin_estacoes['qmed_fev_(m³/s)']*1000))*100).round(2)
sjoin_estacoes['percent_dif_qmed_mar'] = (((sjoin_estacoes['qmed_mar_simulado']-(sjoin_estacoes['qmed_mar_(m³/s)']*1000))/(sjoin_estacoes['qmed_mar_(m³/s)']*1000))*100).round(2)
sjoin_estacoes['percent_dif_qmed_abr'] = (((sjoin_estacoes['qmed_abr_simulado']-(sjoin_estacoes['qmed_abr_(m³/s)']*1000))/(sjoin_estacoes['qmed_abr_(m³/s)']*1000))*100).round(2)
sjoin_estacoes['percent_dif_qmed_mai'] = (((sjoin_estacoes['qmed_mai_simulado']-(sjoin_estacoes['qmed_mai_(m³/s)']*1000))/(sjoin_estacoes['qmed_mai_(m³/s)']*1000))*100).round(2)
sjoin_estacoes['percent_dif_qmed_jun'] = (((sjoin_estacoes['qmed_jun_simulado']-(sjoin_estacoes['qmed_jun_(m³/s)']*1000))/(sjoin_estacoes['qmed_jun_(m³/s)']*1000))*100).round(2)
sjoin_estacoes['percent_dif_qmed_jul'] = (((sjoin_estacoes['qmed_jul_simulado']-(sjoin_estacoes['qmed_jul_(m³/s)']*1000))/(sjoin_estacoes['qmed_jul_(m³/s)']*1000))*100).round(2)
sjoin_estacoes['percent_dif_qmed_ago'] = (((sjoin_estacoes['qmed_ago_simulado']-(sjoin_estacoes['qmed_ago_(m³/s)']*1000))/(sjoin_estacoes['qmed_ago_(m³/s)']*1000))*100).round(2)
sjoin_estacoes['percent_dif_qmed_set'] = (((sjoin_estacoes['qmed_set_simulado']-(sjoin_estacoes['qmed_set_(m³/s)']*1000))/(sjoin_estacoes['qmed_set_(m³/s)']*1000))*100).round(2)
sjoin_estacoes['percent_dif_qmed_out'] = (((sjoin_estacoes['qmed_out_simulado']-(sjoin_estacoes['qmed_out_(m³/s)']*1000))/(sjoin_estacoes['qmed_out_(m³/s)']*1000))*100).round(2)
sjoin_estacoes['percent_dif_qmed_nov'] = (((sjoin_estacoes['qmed_nov_simulado']-(sjoin_estacoes['qmed_nov_(m³/s)']*1000))/(sjoin_estacoes['qmed_nov_(m³/s)']*1000))*100).round(2)
sjoin_estacoes['percent_dif_qmed_dez'] = (((sjoin_estacoes['qmed_dez_simulado']-(sjoin_estacoes['qmed_dez_(m³/s)']*1000))/(sjoin_estacoes['qmed_dez_(m³/s)']*1000))*100).round(2)


sjoin_estacoes['percent_medio_dif_qmed'] = ((sjoin_estacoes['percent_dif_qmed_jan'].abs()+sjoin_estacoes['percent_dif_qmed_fev'].abs()+sjoin_estacoes['percent_dif_qmed_mar'].abs()+
                                           sjoin_estacoes['percent_dif_qmed_abr'].abs()+sjoin_estacoes['percent_dif_qmed_mai'].abs()+sjoin_estacoes['percent_dif_qmed_jun'].abs()+
                                           sjoin_estacoes['percent_dif_qmed_jul'].abs()+sjoin_estacoes['percent_dif_qmed_ago'].abs()+sjoin_estacoes['percent_dif_qmed_set'].abs()+
                                           sjoin_estacoes['percent_dif_qmed_out'].abs()+sjoin_estacoes['percent_dif_qmed_nov'].abs()+sjoin_estacoes['percent_dif_qmed_dez'].abs())/12).round(2)

# %%
#Calculando o erro absoluto e erro relativo

sjoin_estacoes['err_abs_q95_jan'] = (sjoin_estacoes['q95_jan_simulado']-(sjoin_estacoes['q95_jan_(m³/s)']*1000)).round(2)
sjoin_estacoes['err_abs_q95_fev'] = (sjoin_estacoes['q95_fev_simulado']-(sjoin_estacoes['q95_fev_(m³/s)']*1000)).round(2)
sjoin_estacoes['err_abs_q95_mar'] = (sjoin_estacoes['q95_mar_simulado']-(sjoin_estacoes['q95_mar_(m³/s)']*1000)).round(2)
sjoin_estacoes['err_abs_q95_abr'] = (sjoin_estacoes['q95_abr_simulado']-(sjoin_estacoes['q95_abr_(m³/s)']*1000)).round(2)
sjoin_estacoes['err_abs_q95_mai'] = (sjoin_estacoes['q95_mai_simulado']-(sjoin_estacoes['q95_mai_(m³/s)']*1000)).round(2)
sjoin_estacoes['err_abs_q95_jun'] = (sjoin_estacoes['q95_jun_simulado']-(sjoin_estacoes['q95_jun_(m³/s)']*1000)).round(2)
sjoin_estacoes['err_abs_q95_jul'] = (sjoin_estacoes['q95_jul_simulado']-(sjoin_estacoes['q95_jul_(m³/s)']*1000)).round(2)
sjoin_estacoes['err_abs_q95_ago'] = (sjoin_estacoes['q95_ago_simulado']-(sjoin_estacoes['q95_ago_(m³/s)']*1000)).round(2)
sjoin_estacoes['err_abs_q95_set'] = (sjoin_estacoes['q95_set_simulado']-(sjoin_estacoes['q95_set_(m³/s)']*1000)).round(2)
sjoin_estacoes['err_abs_q95_out'] = (sjoin_estacoes['q95_out_simulado']-(sjoin_estacoes['q95_out_(m³/s)']*1000)).round(2)
sjoin_estacoes['err_abs_q95_nov'] = (sjoin_estacoes['q95_nov_simulado']-(sjoin_estacoes['q95_nov_(m³/s)']*1000)).round(2)
sjoin_estacoes['err_abs_q95_dez'] = (sjoin_estacoes['q95_dez_simulado']-(sjoin_estacoes['q95_dez_(m³/s)']*1000)).round(2)

sjoin_estacoes['err_relat_q95_jan'] = ((sjoin_estacoes['err_abs_q95_jan']/sjoin_estacoes['q95_jan_simulado'])*100).round(2)
sjoin_estacoes['err_relat_q95_fev'] = ((sjoin_estacoes['err_abs_q95_fev']/sjoin_estacoes['q95_fev_simulado'])*100).round(2)
sjoin_estacoes['err_relat_q95_mar'] = ((sjoin_estacoes['err_abs_q95_mar']/sjoin_estacoes['q95_mar_simulado'])*100).round(2)
sjoin_estacoes['err_relat_q95_abr'] = ((sjoin_estacoes['err_abs_q95_abr']/sjoin_estacoes['q95_abr_simulado'])*100).round(2)
sjoin_estacoes['err_relat_q95_mai'] = ((sjoin_estacoes['err_abs_q95_mai']/sjoin_estacoes['q95_mai_simulado'])*100).round(2)
sjoin_estacoes['err_relat_q95_jun'] = ((sjoin_estacoes['err_abs_q95_jun']/sjoin_estacoes['q95_jun_simulado'])*100).round(2)
sjoin_estacoes['err_relat_q95_jul'] = ((sjoin_estacoes['err_abs_q95_jul']/sjoin_estacoes['q95_jul_simulado'])*100).round(2)
sjoin_estacoes['err_relat_q95_ago'] = ((sjoin_estacoes['err_abs_q95_ago']/sjoin_estacoes['q95_ago_simulado'])*100).round(2)
sjoin_estacoes['err_relat_q95_set'] = ((sjoin_estacoes['err_abs_q95_set']/sjoin_estacoes['q95_set_simulado'])*100).round(2)
sjoin_estacoes['err_relat_q95_out'] = ((sjoin_estacoes['err_abs_q95_out']/sjoin_estacoes['q95_out_simulado'])*100).round(2)
sjoin_estacoes['err_relat_q95_nov'] = ((sjoin_estacoes['err_abs_q95_nov']/sjoin_estacoes['q95_nov_simulado'])*100).round(2)
sjoin_estacoes['err_relat_q95_dez'] = ((sjoin_estacoes['err_abs_q95_dez']/sjoin_estacoes['q95_dez_simulado'])*100).round(2)





sjoin_estacoes['err_abs_qmed_jan'] = (sjoin_estacoes['qmed_jan_simulado']-(sjoin_estacoes['qmed_jan_(m³/s)']*1000)).round(2)
sjoin_estacoes['err_abs_qmed_fev'] = (sjoin_estacoes['qmed_fev_simulado']-(sjoin_estacoes['qmed_fev_(m³/s)']*1000)).round(2)
sjoin_estacoes['err_abs_qmed_mar'] = (sjoin_estacoes['qmed_mar_simulado']-(sjoin_estacoes['qmed_mar_(m³/s)']*1000)).round(2)
sjoin_estacoes['err_abs_qmed_abr'] = (sjoin_estacoes['qmed_abr_simulado']-(sjoin_estacoes['qmed_abr_(m³/s)']*1000)).round(2)
sjoin_estacoes['err_abs_qmed_mai'] = (sjoin_estacoes['qmed_mai_simulado']-(sjoin_estacoes['qmed_mai_(m³/s)']*1000)).round(2)
sjoin_estacoes['err_abs_qmed_jun'] = (sjoin_estacoes['qmed_jun_simulado']-(sjoin_estacoes['qmed_jun_(m³/s)']*1000)).round(2)
sjoin_estacoes['err_abs_qmed_jul'] = (sjoin_estacoes['qmed_jul_simulado']-(sjoin_estacoes['qmed_jul_(m³/s)']*1000)).round(2)
sjoin_estacoes['err_abs_qmed_ago'] = (sjoin_estacoes['qmed_ago_simulado']-(sjoin_estacoes['qmed_ago_(m³/s)']*1000)).round(2)
sjoin_estacoes['err_abs_qmed_set'] = (sjoin_estacoes['qmed_set_simulado']-(sjoin_estacoes['qmed_set_(m³/s)']*1000)).round(2)
sjoin_estacoes['err_abs_qmed_out'] = (sjoin_estacoes['qmed_out_simulado']-(sjoin_estacoes['qmed_out_(m³/s)']*1000)).round(2)
sjoin_estacoes['err_abs_qmed_nov'] = (sjoin_estacoes['qmed_nov_simulado']-(sjoin_estacoes['qmed_nov_(m³/s)']*1000)).round(2)
sjoin_estacoes['err_abs_qmed_dez'] = (sjoin_estacoes['qmed_dez_simulado']-(sjoin_estacoes['qmed_dez_(m³/s)']*1000)).round(2)

sjoin_estacoes['err_relat_qmed_jan'] = ((sjoin_estacoes['err_abs_qmed_jan']/sjoin_estacoes['qmed_jan_simulado'])*100).round(2)
sjoin_estacoes['err_relat_qmed_fev'] = ((sjoin_estacoes['err_abs_qmed_fev']/sjoin_estacoes['qmed_fev_simulado'])*100).round(2)
sjoin_estacoes['err_relat_qmed_mar'] = ((sjoin_estacoes['err_abs_qmed_mar']/sjoin_estacoes['qmed_mar_simulado'])*100).round(2)
sjoin_estacoes['err_relat_qmed_abr'] = ((sjoin_estacoes['err_abs_qmed_abr']/sjoin_estacoes['qmed_abr_simulado'])*100).round(2)
sjoin_estacoes['err_relat_qmed_mai'] = ((sjoin_estacoes['err_abs_qmed_mai']/sjoin_estacoes['qmed_mai_simulado'])*100).round(2)
sjoin_estacoes['err_relat_qmed_jun'] = ((sjoin_estacoes['err_abs_qmed_jun']/sjoin_estacoes['qmed_jun_simulado'])*100).round(2)
sjoin_estacoes['err_relat_qmed_jul'] = ((sjoin_estacoes['err_abs_qmed_jul']/sjoin_estacoes['qmed_jul_simulado'])*100).round(2)
sjoin_estacoes['err_relat_qmed_ago'] = ((sjoin_estacoes['err_abs_qmed_ago']/sjoin_estacoes['qmed_ago_simulado'])*100).round(2)
sjoin_estacoes['err_relat_qmed_set'] = ((sjoin_estacoes['err_abs_qmed_set']/sjoin_estacoes['qmed_set_simulado'])*100).round(2)
sjoin_estacoes['err_relat_qmed_out'] = ((sjoin_estacoes['err_abs_qmed_out']/sjoin_estacoes['qmed_out_simulado'])*100).round(2)
sjoin_estacoes['err_relat_qmed_nov'] = ((sjoin_estacoes['err_abs_qmed_nov']/sjoin_estacoes['qmed_nov_simulado'])*100).round(2)
sjoin_estacoes['err_relat_qmed_dez'] = ((sjoin_estacoes['err_abs_qmed_dez']/sjoin_estacoes['qmed_dez_simulado'])*100).round(2)
# Out:
# C:\Users\matheus.cgomes\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\geopandas\geodataframe.py:1525: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   super().__setitem__(key, value)
# C:\Users\matheus.cgomes\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\geopandas\geodataframe.py:1525: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   super().__setitem__(key, value)
# C:\Users\matheus.cgomes\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\geopandas\geodataframe.py:1525: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   super().__setitem__(key, value)
# C:\Users\matheus.cgomes\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\geopandas\geodataframe.py:1525: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   super().__setitem__(key, value)
# C:\Users\matheus.cgomes\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\geopandas\geodataframe.py:1525: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   super().__setitem__(key, value)
# C:\Users\matheus.cgomes\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\geopandas\geodataframe.py:1525: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   super().__setitem__(key, value)
# C:\Users\matheus.cgomes\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\geopandas\geodataframe.py:1525: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   super().__setitem__(key, value)
# C:\Users\matheus.cgomes\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\geopandas\geodataframe.py:1525: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   super().__setitem__(key, value)
# C:\Users\matheus.cgomes\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\geopandas\geodataframe.py:1525: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   super().__setitem__(key, value)
# C:\Users\matheus.cgomes\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\geopandas\geodataframe.py:1525: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   super().__setitem__(key, value)
# C:\Users\matheus.cgomes\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\geopandas\geodataframe.py:1525: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   super().__setitem__(key, value)
# C:\Users\matheus.cgomes\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\geopandas\geodataframe.py:1525: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   super().__setitem__(key, value)
# C:\Users\matheus.cgomes\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\geopandas\geodataframe.py:1525: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   super().__setitem__(key, value)
# C:\Users\matheus.cgomes\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\geopandas\geodataframe.py:1525: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   super().__setitem__(key, value)
# C:\Users\matheus.cgomes\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\geopandas\geodataframe.py:1525: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   super().__setitem__(key, value)
# C:\Users\matheus.cgomes\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\geopandas\geodataframe.py:1525: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   super().__setitem__(key, value)
# C:\Users\matheus.cgomes\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\geopandas\geodataframe.py:1525: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   super().__setitem__(key, value)
# C:\Users\matheus.cgomes\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\geopandas\geodataframe.py:1525: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   super().__setitem__(key, value)
# C:\Users\matheus.cgomes\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\geopandas\geodataframe.py:1525: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   super().__setitem__(key, value)
# C:\Users\matheus.cgomes\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\geopandas\geodataframe.py:1525: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   super().__setitem__(key, value)
# C:\Users\matheus.cgomes\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\geopandas\geodataframe.py:1525: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   super().__setitem__(key, value)
# C:\Users\matheus.cgomes\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\geopandas\geodataframe.py:1525: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   super().__setitem__(key, value)
# C:\Users\matheus.cgomes\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\geopandas\geodataframe.py:1525: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   super().__setitem__(key, value)
# C:\Users\matheus.cgomes\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\geopandas\geodataframe.py:1525: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   super().__setitem__(key, value)
# C:\Users\matheus.cgomes\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\geopandas\geodataframe.py:1525: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   super().__setitem__(key, value)
# C:\Users\matheus.cgomes\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\geopandas\geodataframe.py:1525: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   super().__setitem__(key, value)
# C:\Users\matheus.cgomes\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\geopandas\geodataframe.py:1525: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   super().__setitem__(key, value)
# C:\Users\matheus.cgomes\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\geopandas\geodataframe.py:1525: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   super().__setitem__(key, value)
# C:\Users\matheus.cgomes\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\geopandas\geodataframe.py:1525: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   super().__setitem__(key, value)
# C:\Users\matheus.cgomes\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\geopandas\geodataframe.py:1525: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   super().__setitem__(key, value)
# C:\Users\matheus.cgomes\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\geopandas\geodataframe.py:1525: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   super().__setitem__(key, value)
# C:\Users\matheus.cgomes\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\geopandas\geodataframe.py:1525: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   super().__setitem__(key, value)
# C:\Users\matheus.cgomes\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\geopandas\geodataframe.py:1525: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   super().__setitem__(key, value)
# C:\Users\matheus.cgomes\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\geopandas\geodataframe.py:1525: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   super().__setitem__(key, value)

# %%
sjoin_estacoes.columns
# Out:
# Index(['id_left', 'codigo', 'codalt', 'nome', 'rio', 'adkm2', 'anoinicio',
#        'anofim', 'anototal', 'q95_jan_(m³/s)',
#        ...
#        'err_relat_qmed_mar', 'err_relat_qmed_abr', 'err_relat_qmed_mai',
#        'err_relat_qmed_jun', 'err_relat_qmed_jul', 'err_relat_qmed_ago',
#        'err_relat_qmed_set', 'err_relat_qmed_out', 'err_relat_qmed_nov',
#        'err_relat_qmed_dez'],
#       dtype='object', length=208)

# %%
sjoin_estacoes[['percent_dif_q95_jan',
       'percent_dif_q95_fev', 'percent_dif_q95_mar', 'percent_dif_q95_abr',
       'percent_dif_q95_mai', 'percent_dif_q95_jun', 'percent_dif_q95_jul',
       'percent_dif_q95_ago', 'percent_dif_q95_set', 'percent_dif_q95_out',
       'percent_dif_q95_nov', 'percent_dif_q95_dez',   'percent_medio_dif_q95',
         'percent_dif_qmed_jan',
       'percent_dif_qmed_fev', 'percent_dif_qmed_mar', 'percent_dif_qmed_abr',
       'percent_dif_qmed_mai', 'percent_dif_qmed_jun', 'percent_dif_qmed_jul',
       'percent_dif_qmed_ago', 'percent_dif_qmed_set', 'percent_dif_qmed_out',
       'percent_dif_qmed_nov', 'percent_dif_qmed_dez',
       'percent_medio_dif_qmed']].describe()
# Out:
#        percent_dif_q95_jan  percent_dif_q95_fev  percent_dif_q95_mar  \
# count            64.000000            64.000000             64.00000
# mean             -2.088125            -2.050156             -2.01625
# std               8.483378             8.204190              8.02859
# min             -51.540000           -51.540000            -51.54000
# 25%               0.000000             0.000000              0.00000
# 50%               0.000000             0.000000              0.00000
# 75%               0.000000             0.000000              0.00000
# max               4.450000             3.600000              2.93000
#
#        percent_dif_q95_abr  percent_dif_q95_mai  percent_dif_q95_jun  \
# count            64.000000            64.000000            64.000000
# mean             -2.096875            -1.984375            -2.055625
# std               8.287928             8.494778             8.566579
# min             -51.540000           -51.540000           -51.540000
# 25%               0.000000             0.000000             0.000000
# 50%               0.000000             0.000000             0.000000
# 75%               0.000000             0.000000             0.000000
# max               2.910000             4.760000             4.600000
#
#        percent_dif_q95_jul  percent_dif_q95_ago  percent_dif_q95_set  \
# count            64.000000            62.000000            62.000000
# mean             -1.902969            -1.929194            -2.008387
# std               8.825282             9.161397             9.249991
# min             -51.540000           -51.540000           -51.540000
# 25%               0.000000             0.000000             0.000000
# 50%               0.000000             0.000000             0.000000
# 75%               0.000000             0.000000             0.000000
# max               5.880000             7.900000             9.550000
#
#        percent_dif_q95_out  ...  percent_dif_qmed_abr  percent_dif_qmed_mai  \
# count            62.000000  ...             64.000000             64.000000
# mean             -2.002742  ...             -1.992969             -1.960156
# std               9.205531  ...              7.965681              8.212508
# min             -51.540000  ...            -51.540000            -51.540000
# 25%              -0.007500  ...              0.000000              0.000000
# 50%               0.000000  ...              0.000000              0.000000
# 75%               0.000000  ...              0.000000              0.000000
# max               8.440000  ...              1.940000              3.290000
#
#        percent_dif_qmed_jun  percent_dif_qmed_jul  percent_dif_qmed_ago  \
# count             64.000000             64.000000             64.000000
# mean              -1.932500             -1.898281             -1.888281
# std                8.393181              8.517386              8.712486
# min              -51.540000            -51.540000            -51.540000
# 25%                0.000000              0.000000              0.000000
# 50%                0.000000              0.000000              0.000000
# 75%                0.000000              0.000000              0.000000
# max                4.090000              4.780000              5.790000
#
#        percent_dif_qmed_set  percent_dif_qmed_out  percent_dif_qmed_nov  \
# count             64.000000             64.000000             64.000000
# mean              -1.894844             -1.796094             -1.809219
# std                8.751232              8.645141              8.224703
# min              -51.540000            -51.540000            -51.540000
# 25%                0.000000              0.000000              0.000000
# 50%                0.000000              0.000000             -0.000000
# 75%                0.000000              0.000000              0.000000
# max                5.470000              7.520000              6.340000
#
#        percent_dif_qmed_dez  percent_medio_dif_qmed
# count             64.000000               64.000000
# mean              -1.900937                2.415938
# std                7.977316                8.031105
# min              -51.540000                0.000000
# 25%                0.000000                0.000000
# 50%               -0.000000                0.000000
# 75%                0.000000                0.075000
# max                4.210000               51.540000
#
# [8 rows x 26 columns]

# %%
filtro1 = sjoin_estacoes['percent_medio_dif_q95']>0
filtro2 = ((sjoin_estacoes['percent_dif_q95_jan']>10) | (sjoin_estacoes['percent_dif_q95_fev']>10) |(sjoin_estacoes['percent_dif_q95_mar']>10) |
           (sjoin_estacoes['percent_dif_q95_abr']>10) |(sjoin_estacoes['percent_dif_q95_mai']>10) |(sjoin_estacoes['percent_dif_q95_jun']>10) |
           (sjoin_estacoes['percent_dif_q95_jul']>10) |(sjoin_estacoes['percent_dif_q95_ago']>10) |(sjoin_estacoes['percent_dif_q95_set']>10) |
           (sjoin_estacoes['percent_dif_q95_out']>10) |(sjoin_estacoes['percent_dif_q95_nov']>10) |(sjoin_estacoes['percent_dif_q95_dez']>10))
sjoin_estacoes.loc[filtro2]
# Out:
# Empty GeoDataFrame
# Columns: [id_left, codigo, codalt, nome, rio, adkm2, anoinicio, anofim, anototal, q95_jan_(m³/s), q95_fev_(m³/s), q95_mar_(m³/s), q95_abr_(m³/s), q95_mai_(m³/s), q95_jun_(m³/s), q95_jul_(m³/s), q95_ago_(m³/s), q95_set_(m³/s), q95_out_(m³/s), q95_nov_(m³/s), q95_dez_(m³/s), qmed_jan_(m³/s), qmed_fev_(m³/s), qmed_mar_(m³/s), qmed_abr_(m³/s), qmed_mai_(m³/s), qmed_jun_(m³/s), qmed_jul_(m³/s), qmed_ago_(m³/s), qmed_set_(m³/s), qmed_out_(m³/s), qmed_nov_(m³/s), qmed_dez_(m³/s), geometry, index_right, id_right, cobacia, cocursodag, noorigem, nodestino, nucomptrec, nudistbact, nudistcdag, nuareacont, nuareamont, nogenerico, noligacao, noespecif, noriocomp, nooriginal, cocdadesag, nutrjus, nudistbacc, nuareabacc, nuordemcda, nucompcda, nunivotto, nunivotcda, nustrahler, dedominial, dsversao, cobacia_jus, q95_jan, q95_fev, q95_mar, q95_abr, q95_mai, q95_jun, q95_jul, q95_ago, q95_set, q95_out, q95_nov, q95_dez, qmed_jan, qmed_fev, qmed_mar, qmed_abr, qmed_mai, qmed_jun, qmed_jul, qmed_ago, qmed_set, qmed_out, qmed_nov, qmed_dez, q95_esp_jan, q95_esp_fev, q95_esp_mar, q95_esp_abr, q95_esp_mai, q95_esp_jun, q95_esp_jul, q95_esp_ago, q95_esp_set, q95_esp_out, q95_esp_nov, q95_esp_dez, qmed_esp_jan, qmed_esp_fev, ...]
# Index: []
#
# [0 rows x 208 columns]

# %%
sjoin_estacoes.info(verbose=True)
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# Index: 64 entries, 0 to 66
# Data columns (total 208 columns):
#  #    Column                  Dtype
# ---   ------                  -----
#  0    id_left                 int64
#  1    codigo                  object
#  2    codalt                  object
#  3    nome                    object
#  4    rio                     object
#  5    adkm2                   int32
#  6    anoinicio               object
#  7    anofim                  object
#  8    anototal                object
#  9    q95_jan_(m³/s)          float64
#  10   q95_fev_(m³/s)          float64
#  11   q95_mar_(m³/s)          float64
#  12   q95_abr_(m³/s)          float64
#  13   q95_mai_(m³/s)          float64
#  14   q95_jun_(m³/s)          float64
#  15   q95_jul_(m³/s)          float64
#  16   q95_ago_(m³/s)          float64
#  17   q95_set_(m³/s)          float64
#  18   q95_out_(m³/s)          float64
#  19   q95_nov_(m³/s)          float64
#  20   q95_dez_(m³/s)          float64
#  21   qmed_jan_(m³/s)         float64
#  22   qmed_fev_(m³/s)         float64
#  23   qmed_mar_(m³/s)         float64
#  24   qmed_abr_(m³/s)         float64
#  25   qmed_mai_(m³/s)         float64
#  26   qmed_jun_(m³/s)         float64
#  27   qmed_jul_(m³/s)         float64
#  28   qmed_ago_(m³/s)         float64
#  29   qmed_set_(m³/s)         float64
#  30   qmed_out_(m³/s)         float64
#  31   qmed_nov_(m³/s)         float64
#  32   qmed_dez_(m³/s)         float64
#  33   geometry                geometry
#  34   index_right             int64
#  35   id_right                float64
#  36   cobacia                 object
#  37   cocursodag              object
#  38   noorigem                float64
#  39   nodestino               float64
#  40   nucomptrec              float64
#  41   nudistbact              float64
#  42   nudistcdag              float64
#  43   nuareacont              float64
#  44   nuareamont              float64
#  45   nogenerico              object
#  46   noligacao               object
#  47   noespecif               object
#  48   noriocomp               object
#  49   nooriginal              object
#  50   cocdadesag              object
#  51   nutrjus                 float64
#  52   nudistbacc              float64
#  53   nuareabacc              float64
#  54   nuordemcda              float64
#  55   nucompcda               float64
#  56   nunivotto               float64
#  57   nunivotcda              float64
#  58   nustrahler              float64
#  59   dedominial              object
#  60   dsversao                object
#  61   cobacia_jus             object
#  62   q95_jan                 float64
#  63   q95_fev                 float64
#  64   q95_mar                 float64
#  65   q95_abr                 float64
#  66   q95_mai                 float64
#  67   q95_jun                 float64
#  68   q95_jul                 float64
#  69   q95_ago                 float64
#  70   q95_set                 float64
#  71   q95_out                 float64
#  72   q95_nov                 float64
#  73   q95_dez                 float64
#  74   qmed_jan                float64
#  75   qmed_fev                float64
#  76   qmed_mar                float64
#  77   qmed_abr                float64
#  78   qmed_mai                float64
#  79   qmed_jun                float64
#  80   qmed_jul                float64
#  81   qmed_ago                float64
#  82   qmed_set                float64
#  83   qmed_out                float64
#  84   qmed_nov                float64
#  85   qmed_dez                float64
#  86   q95_esp_jan             float64
#  87   q95_esp_fev             float64
#  88   q95_esp_mar             float64
#  89   q95_esp_abr             float64
#  90   q95_esp_mai             float64
#  91   q95_esp_jun             float64
#  92   q95_esp_jul             float64
#  93   q95_esp_ago             float64
#  94   q95_esp_set             float64
#  95   q95_esp_out             float64
#  96   q95_esp_nov             float64
#  97   q95_esp_dez             float64
#  98   qmed_esp_jan            float64
#  99   qmed_esp_fev            float64
#  100  qmed_esp_mar            float64
#  101  qmed_esp_abr            float64
#  102  qmed_esp_mai            float64
#  103  qmed_esp_jun            float64
#  104  qmed_esp_jul            float64
#  105  qmed_esp_ago            float64
#  106  qmed_esp_set            float64
#  107  qmed_esp_out            float64
#  108  qmed_esp_nov            float64
#  109  qmed_esp_dez            float64
#  110  q95_jan_simulado        float64
#  111  q95_fev_simulado        float64
#  112  q95_mar_simulado        float64
#  113  q95_abr_simulado        float64
#  114  q95_mai_simulado        float64
#  115  q95_jun_simulado        float64
#  116  q95_jul_simulado        float64
#  117  q95_ago_simulado        float64
#  118  q95_set_simulado        float64
#  119  q95_out_simulado        float64
#  120  q95_nov_simulado        float64
#  121  q95_dez_simulado        float64
#  122  qmed_jan_simulado       float64
#  123  qmed_fev_simulado       float64
#  124  qmed_mar_simulado       float64
#  125  qmed_abr_simulado       float64
#  126  qmed_mai_simulado       float64
#  127  qmed_jun_simulado       float64
#  128  qmed_jul_simulado       float64
#  129  qmed_ago_simulado       float64
#  130  qmed_set_simulado       float64
#  131  qmed_out_simulado       float64
#  132  qmed_nov_simulado       float64
#  133  qmed_dez_simulado       float64
#  134  percent_dif_q95_jan     float64
#  135  percent_dif_q95_fev     float64
#  136  percent_dif_q95_mar     float64
#  137  percent_dif_q95_abr     float64
#  138  percent_dif_q95_mai     float64
#  139  percent_dif_q95_jun     float64
#  140  percent_dif_q95_jul     float64
#  141  percent_dif_q95_ago     float64
#  142  percent_dif_q95_set     float64
#  143  percent_dif_q95_out     float64
#  144  percent_dif_q95_nov     float64
#  145  percent_dif_q95_dez     float64
#  146  percent_medio_dif_q95   float64
#  147  percent_dif_qmed_jan    float64
#  148  percent_dif_qmed_fev    float64
#  149  percent_dif_qmed_mar    float64
#  150  percent_dif_qmed_abr    float64
#  151  percent_dif_qmed_mai    float64
#  152  percent_dif_qmed_jun    float64
#  153  percent_dif_qmed_jul    float64
#  154  percent_dif_qmed_ago    float64
#  155  percent_dif_qmed_set    float64
#  156  percent_dif_qmed_out    float64
#  157  percent_dif_qmed_nov    float64
#  158  percent_dif_qmed_dez    float64
#  159  percent_medio_dif_qmed  float64
#  160  err_abs_q95_jan         float64
#  161  err_abs_q95_fev         float64
#  162  err_abs_q95_mar         float64
#  163  err_abs_q95_abr         float64
#  164  err_abs_q95_mai         float64
#  165  err_abs_q95_jun         float64
#  166  err_abs_q95_jul         float64
#  167  err_abs_q95_ago         float64
#  168  err_abs_q95_set         float64
#  169  err_abs_q95_out         float64
#  170  err_abs_q95_nov         float64
#  171  err_abs_q95_dez         float64
#  172  err_relat_q95_jan       float64
#  173  err_relat_q95_fev       float64
#  174  err_relat_q95_mar       float64
#  175  err_relat_q95_abr       float64
#  176  err_relat_q95_mai       float64
#  177  err_relat_q95_jun       float64
#  178  err_relat_q95_jul       float64
#  179  err_relat_q95_ago       float64
#  180  err_relat_q95_set       float64
#  181  err_relat_q95_out       float64
#  182  err_relat_q95_nov       float64
#  183  err_relat_q95_dez       float64
#  184  err_abs_qmed_jan        float64
#  185  err_abs_qmed_fev        float64
#  186  err_abs_qmed_mar        float64
#  187  err_abs_qmed_abr        float64
#  188  err_abs_qmed_mai        float64
#  189  err_abs_qmed_jun        float64
#  190  err_abs_qmed_jul        float64
#  191  err_abs_qmed_ago        float64
#  192  err_abs_qmed_set        float64
#  193  err_abs_qmed_out        float64
#  194  err_abs_qmed_nov        float64
#  195  err_abs_qmed_dez        float64
#  196  err_relat_qmed_jan      float64
#  197  err_relat_qmed_fev      float64
#  198  err_relat_qmed_mar      float64
#  199  err_relat_qmed_abr      float64
#  200  err_relat_qmed_mai      float64
#  201  err_relat_qmed_jun      float64
#  202  err_relat_qmed_jul      float64
#  203  err_relat_qmed_ago      float64
#  204  err_relat_qmed_set      float64
#  205  err_relat_qmed_out      float64
#  206  err_relat_qmed_nov      float64
#  207  err_relat_qmed_dez      float64
# dtypes: float64(186), geometry(1), int32(1), int64(2), object(18)
# memory usage: 104.2+ KB

# %%
#sjoin_estacoes.drop(columns='fid',inplace=True)
sjoin_estacoes.to_file('D:\\matheus.cgomes\\Documentos\\GitHub\\gis_automations\\data\\17-06-2024\\68_estacoes_dif_17-06-2024.gpkg')
